# %%
import tensorflow as tf
import numpy as np
import json
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import KFold

# Function to resize labels
def resize_labels(labels, original_size, new_size):
    # Adjust the label coordinates for the new image size
    scale_x = new_size[1] / original_size[1]
    scale_y = new_size[0] / original_size[0]
    resized_labels = []
    for label in labels:
        resized_label = {
            'x': label['x'] * scale_x,
            'y': label['y'] * scale_y,
            'radius': label['radius'] * scale_x  # Assuming uniform scaling in x and y
        }
        resized_labels.append(resized_label)
    return resized_labels


# Function to convert labels to EfficientDet format
def convert_to_efficientdet_format(labels, image_shape):
    efficientdet_labels = []
    for label in labels:
        # Calculate the coordinates of the upper left and lower right corners
        xmin = (label['x'] - label['radius']) / image_shape[1]
        ymin = (label['y'] - label['radius']) / image_shape[0]
        xmax = (label['x'] + label['radius']) / image_shape[1]
        ymax = (label['y'] + label['radius']) / image_shape[0]
        # EfficientDet format [ymin, xmin, ymax, xmax]
        efficientdet_labels.append([
            max(0, ymin), max(0, xmin), min(1, ymax), min(1, xmax)
        ])
    return efficientdet_labels


# Function to load images and labels
def load_images_and_labels(image_dir, label_dir, original_size=(1024, 1024), new_size=(512, 512)):
    image_files = [os.path.join(image_dir, file) for file in sorted(os.listdir(image_dir)) if file.endswith('.png')]
    label_files = [os.path.join(label_dir, file) for file in sorted(os.listdir(label_dir)) if file.endswith('.json')]
    
    images = []
    all_boxes = []

    for image_file, label_file in zip(image_files, label_files):
        # Load and resize image
        image = load_img(image_file, color_mode='rgb', target_size=new_size)
        # Convert the image to an array and scale the pixel values to [-1, 1]
        image = (img_to_array(image) / 127.5) - 1
        images.append(image)

        # Load labels and adjust for new image size
        with open(label_file, 'r') as file:
            json_data = json.load(file)
        resized_json_data = resize_labels(json_data, original_size=original_size, new_size=new_size)
        boxes = convert_to_efficientdet_format(resized_json_data, new_size)
        all_boxes.append(boxes)
    
    return np.array(images), all_boxes


# Function to pad labels to a fixed size
def pad_labels(labels, max_boxes=250, pad_value=0):
    padded_labels = []
    for label in labels:
        padded_label = np.zeros((max_boxes, 4), dtype=np.float32) + pad_value
        num_boxes = min(len(label), max_boxes)
        padded_label[:num_boxes] = label[:num_boxes]
        padded_labels.append(padded_label)
    return np.array(padded_labels)

# Function to prepare the dataset
def prepare_dataset(images, boxes, batch_size, num_boxes=250):
    images = tf.constant(images, dtype=tf.float32)
    boxes = pad_labels(boxes, max_boxes=num_boxes)
    boxes = tf.constant(boxes, dtype=tf.float32)

    dataset = tf.data.Dataset.from_tensor_slices((images, boxes))
    dataset = dataset.shuffle(len(images)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
batch_size = 2
image_dir = './TMA_WSI_Padded_PNGs'
label_dir = './TMA_WSI_Labels_updated'
images, boxes = load_images_and_labels(image_dir, label_dir)
# Map this preprocessing function to your dataset


# Assuming we have only one class for object detection and 100 boxes per image
num_boxes = 250  # Maximum number of boxes per image, adjust as needed

dataset = prepare_dataset(images, boxes, batch_size, num_boxes=num_boxes)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

def create_object_detection_model(num_boxes, dropout_rate=0.1, l2_lambda=0.01, fine_tune_at=100):
    backbone = tf.keras.applications.MobileNetV2(input_shape=[512, 512, 3], include_top=False, weights='imagenet')

    # Unfreeze the top layers of the model
    backbone.trainable = True
    for layer in backbone.layers[:fine_tune_at]:
        layer.trainable = False

    x = backbone.output

    # Convolutional layers with Batch Normalization and L2 Regularization
    x = layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same', 
                      kernel_regularizer=regularizers.l2(l2_lambda))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(l2_lambda))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(l2_lambda))(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)

    # Dropout layer
    x = layers.Dropout(dropout_rate)(x)

    # Output layer for bounding box predictions
    boxes_output_flat = layers.Dense(num_boxes * 4, activation='sigmoid', name='boxes_output')(x)
    boxes_output = layers.Reshape((num_boxes, 4))(boxes_output_flat)

    model = models.Model(inputs=backbone.input, outputs=boxes_output)
    
    return model


model = create_object_detection_model(num_boxes)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler
import datetime
import os

# Define the Smooth L1 Loss Function
def smooth_l1_loss(sigma=3.0):
    sigma_squared = sigma ** 2
    
    def smooth_l1_loss_fixed(y_true, y_pred):
        regression_diff = y_true - y_pred
        regression_diff = tf.abs(regression_diff)
        regression_loss = tf.where(
            tf.less(regression_diff, 1.0 / sigma_squared),
            0.5 * sigma_squared * tf.pow(regression_diff, 2),
            regression_diff - 0.5 / sigma_squared
        )
        regression_loss = tf.reduce_sum(regression_loss, axis=-1)
        return tf.reduce_mean(regression_loss)
    
    return smooth_l1_loss_fixed
# Compile the Model with the Custom Loss
model.compile(optimizer='adam',
              loss=smooth_l1_loss(),  # Only use smooth L1 loss for bounding box predictions
              metrics=['mean_squared_error'])  # Added a metric for bounding box prediction quality

# Set up TensorBoard logging
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Set up checkpoints to save the model
checkpoint_dir = "checkpoints/"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
checkpoint_path = checkpoint_dir + "cp-{epoch:04d}.ckpt"
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_best_only=False  # Set to True to save only the best model based on validation loss
)

# Define a Learning Rate Schedule
def scheduler(epoch, lr):
    if epoch < 100:
        return lr
    elif epoch%10 == 0:
        return lr * tf.math.exp(-0.1)
    else:
        return lr

learning_rate_callback = LearningRateScheduler(scheduler)

# %%
# Initialize a list to store the results
results = []

# Split the dataset into 10 folds
kf = KFold(n_splits=5, shuffle=True, random_state=42)

fold_no = 1
for train_index, val_index in kf.split(images):
    train_images, val_images = images[train_index], images[val_index]
    train_boxes, val_boxes = [boxes[i] for i in train_index], [boxes[i] for i in val_index]

    # Prepare the training and validation datasets
    train_dataset = prepare_dataset(train_images, train_boxes, batch_size, num_boxes=num_boxes)
    val_dataset = prepare_dataset(val_images, val_boxes, batch_size, num_boxes=num_boxes)

    # Create a new instance of the model (to reset weights)
    model = create_object_detection_model(num_boxes)

    # Compile the model
    model.compile(optimizer='adam', loss=smooth_l1_loss(), metrics=['mean_squared_error'])

    print(f'Training for fold {fold_no} ...')

    # Fit the model
    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=500,
        callbacks=[tensorboard_callback, checkpoint_callback, learning_rate_callback]
    )

    # Save the model
    model.save(f'model_fold_{fold_no}_dropout.h5')

    # Log the results
    val_loss, val_mse = model.evaluate(val_dataset)
    results.append({'fold': fold_no, 'val_loss': val_loss, 'val_mse': val_mse})

    # Increase the fold number
    fold_no += 1
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Training for fold 1 ...
# Epoch 1/500
# 8/8 [==============================] - ETA: 0s - loss: 5.9039 - mean_squared_error: 0.1424
# Epoch 1: saving model to checkpoints/cp-0001.ckpt
# 8/8 [==============================] - 4s 371ms/step - loss: 5.9039 - mean_squared_error: 0.1424 - val_loss: 3.4577 - val_mean_squared_error: 0.1066 - lr: 0.0010
# Epoch 2/500
# 8/8 [==============================] - ETA: 0s - loss: 2.8580 - mean_squared_error: 0.1408
# Epoch 2: saving model to checkpoints/cp-0002.ckpt
# 8/8 [==============================] - 2s 330ms/step - loss: 2.8580 - mean_squared_error: 0.1408 - val_loss: 1.8643 - val_mean_squared_error: 0.1062 - lr: 0.0010
# Epoch 3/500
# 8/8 [==============================] - ETA: 0s - loss: 1.8201 - mean_squared_error: 0.1389
# Epoch 3: saving model to checkpoints/cp-0003.ckpt
# 8/8 [==============================] - 3s 344ms/step - loss: 1.8201 - mean_squared_error: 0.1389 - val_loss: 1.3800 - val_mean_squared_error: 0.1064 - lr: 0.0010
# Epoch 4/500
# 8/8 [==============================] - ETA: 0s - loss: 1.4844 - mean_squared_error: 0.1359
# Epoch 4: saving model to checkpoints/cp-0004.ckpt
# 8/8 [==============================] - 2s 306ms/step - loss: 1.4844 - mean_squared_error: 0.1359 - val_loss: 1.1920 - val_mean_squared_error: 0.1084 - lr: 0.0010
# Epoch 5/500
# 8/8 [==============================] - ETA: 0s - loss: 1.2707 - mean_squared_error: 0.1286
# Epoch 5: saving model to checkpoints/cp-0005.ckpt
# 8/8 [==============================] - 2s 290ms/step - loss: 1.2707 - mean_squared_error: 0.1286 - val_loss: 1.0843 - val_mean_squared_error: 0.1183 - lr: 0.0010
# Epoch 6/500
# 8/8 [==============================] - ETA: 0s - loss: 1.1984 - mean_squared_error: 0.1331
# Epoch 6: saving model to checkpoints/cp-0006.ckpt
# 8/8 [==============================] - 2s 293ms/step - loss: 1.1984 - mean_squared_error: 0.1331 - val_loss: 0.9697 - val_mean_squared_error: 0.1070 - lr: 0.0010
# Epoch 7/500
# 8/8 [==============================] - ETA: 0s - loss: 1.0870 - mean_squared_error: 0.1250
# Epoch 7: saving model to checkpoints/cp-0007.ckpt
# 8/8 [==============================] - 2s 300ms/step - loss: 1.0870 - mean_squared_error: 0.1250 - val_loss: 1.0337 - val_mean_squared_error: 0.1227 - lr: 0.0010
# Epoch 8/500
# 8/8 [==============================] - ETA: 0s - loss: 1.0161 - mean_squared_error: 0.1179
# Epoch 8: saving model to checkpoints/cp-0008.ckpt
500
# 8/8 [==============================] - ETA: 0s - loss: 0.4728 - mean_squared_error: 0.0502
# Epoch 107: saving model to checkpoints/cp-0107.ckpt
# 8/8 [==============================] - 2s 298ms/step - loss: 0.4728 - mean_squared_error: 0.0502 - val_loss: 0.8427 - val_mean_squared_error: 0.1089 - lr: 9.0484e-04
# Epoch 108/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4208 - mean_squared_error: 0.0430
# Epoch 108: saving model to checkpoints/cp-0108.ckpt
# 8/8 [==============================] - 2s 297ms/step - loss: 0.4208 - mean_squared_error: 0.0430 - val_loss: 1.0586 - val_mean_squared_error: 0.1394 - lr: 9.0484e-04
# Epoch 109/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4313 - mean_squared_error: 0.0429
# Epoch 109: saving model to checkpoints/cp-0109.ckpt
# 8/8 [==============================] - 2s 294ms/step - loss: 0.4313 - mean_squared_error: 0.0429 - val_loss: 1.1759 - val_mean_squared_error: 0.1846 - lr: 9.0484e-04
# Epoch 110/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4345 - mean_squared_error: 0.0448
# Epoch 110: saving model to checkpoints/cp-0110.ckpt
# 8/8 [==============================] - 2s 294ms/step - loss: 0.4345 - mean_squared_error: 0.0448 - val_loss: 1.0102 - val_mean_squared_error: 0.1460 - lr: 9.0484e-04
# Epoch 111/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4553 - mean_squared_error: 0.0451
# Epoch 111: saving model to checkpoints/cp-0111.ckpt
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4553 - mean_squared_error: 0.0451 - val_loss: 1.2982 - val_mean_squared_error: 0.2040 - lr: 8.1873e-04
# Epoch 112/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4814 - mean_squared_error: 0.0482
# Epoch 112: saving model to checkpoints/cp-0112.ckpt
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4814 - mean_squared_error: 0.0482 - val_loss: 0.8673 - val_mean_squared_error: 0.1087 - lr: 8.1873e-04
# Epoch 113/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4318 - mean_squared_error: 0.0418
# Epoch 113: saving model to checkpoints/cp-0113.ckpt
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4318 - mean_squared_error: 0.0418 - val_loss: 0.8865 - val_mean_squared_error: 0.1090 - lr: 8.1873e-04
# Epoch 114/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4342 - mean_squared_error: 0.0442
# Epoch 114: saving model to checkpoints/cp-0114.ckpt
# 8/8 [==============================] - 2s 322ms/step - loss: 0.4342 - mean_squared_error: 0.0442 - val_loss: 0.9199 - val_mean_squared_error: 0.1273 - lr: 8.1873e-04
# Epoch 115/500
# 8/8 [==============================] - ETA: 0s - loss: 0.5024 - mean_squared_error: 0.0565
# Epoch 115: saving model to checkpoints/cp-0115.ckpt
# 8/8 [==============================] - 2s 333ms/step - loss: 0.5024 - mean_squared_error: 0.0565 - val_loss: 1.1139 - val_mean_squared_error: 0.1694 - lr: 8.1873e-04
# Epoch 116/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4250 - mean_squared_error: 0.0408
# Epoch 116: saving model to checkpoints/cp-0116.ckpt
# 8/8 [==============================] - 3s 336ms/step - loss: 0.4250 - mean_squared_error: 0.0408 - val_loss: 0.9200 - val_mean_squared_error: 0.1267 - lr: 8.1873e-04
# Epoch 117/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3771 - mean_squared_error: 0.0347
# Epoch 117: saving model to checkpoints/cp-0117.ckpt
# 8/8 [==============================] - 2s 324ms/step - loss: 0.3771 - mean_squared_error: 0.0347 - val_loss: 1.1822 - val_mean_squared_error: 0.1913 - lr: 8.1873e-04
# Epoch 118/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4090 - mean_squared_error: 0.0413
# Epoch 118: saving model to checkpoints/cp-0118.ckpt
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4090 - mean_squared_error: 0.0413 - val_loss: 0.8648 - val_mean_squared_error: 0.1224 - lr: 8.1873e-04
# Epoch 119/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3769 - mean_squared_error: 0.0373
# Epoch 119: saving model to checkpoints/cp-0119.ckpt
# 8/8 [==============================] - 2s 299ms/step - loss: 0.3769 - mean_squared_error: 0.0373 - val_loss: 0.8688 - val_mean_squared_error: 0.1108 - lr: 8.1873e-04
# Epoch 120/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3601 - mean_squared_error: 0.0346
# Epoch 120: saving model to checkpoints/cp-0120.ckpt
# 8/8 [==============================] - 2s 310ms/step - loss: 0.3601 - mean_squared_error: 0.0346 - val_loss: 0.7753 - val_mean_squared_error: 0.0980 - lr: 8.1873e-04
# Epoch 121/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4696 - mean_squared_error: 0.0496
# Epoch 121: saving model to checkpoints/cp-0121.ckpt
# 8/8 [==============================] - 2s 332ms/step - loss: 0.4696 - mean_squared_error: 0.0496 - val_loss: 0.8322 - val_mean_squared_error: 0.0953 - lr: 7.4082e-04
# Epoch 122/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4293 - mean_squared_error: 0.0415
# Epoch 122: saving model to checkpoints/cp-0122.ckpt
# 8/8 [==============================] - 3s 341ms/step - loss: 0.4293 - mean_squared_error: 0.0415 - val_loss: 1.2640 - val_mean_squared_error: 0.1813 - lr: 7.4082e-04
# Epoch 123/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4320 - mean_squared_error: 0.0378
# Epoch 123: saving model to checkpoints/cp-0123.ckpt
# 8/8 [==============================] - 2s 333ms/step - loss: 0.4320 - mean_squared_error: 0.0378 - val_loss: 1.1173 - val_mean_squared_error: 0.1460 - lr: 7.4082e-04
# Epoch 124/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3864 - mean_squared_error: 0.0311
# Epoch 124: saving model to checkpoints/cp-0124.ckpt
# 8/8 [==============================] - 2s 303ms/step - loss: 0.3864 - mean_squared_error: 0.0311 - val_loss: 0.9675 - val_mean_squared_error: 0.1266 - lr: 7.4082e-04
# Epoch 125/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4494 - mean_squared_error: 0.0469
# Epoch 125: saving model to checkpoints/cp-0125.ckpt
# 8/8 [==============================] - 2s 301ms/step - loss: 0.4494 - mean_squared_error: 0.0469 - val_loss: 0.9139 - val_mean_squared_error: 0.1240 - lr: 7.4082e-04
# Epoch 126/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3722 - mean_squared_error: 0.0336
# Epoch 126: saving model to checkpoints/cp-0126.ckpt
# 8/8 [==============================] - 2s 294ms/step - loss: 0.3722 - mean_squared_error: 0.0336 - val_loss: 0.9342 - val_mean_squared_error: 0.1167 - lr: 7.4082e-04
# Epoch 127/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4787 - mean_squared_error: 0.0523
# Epoch 127: saving model to checkpoints/cp-0127.ckpt
# 8/8 [==============================] - 2s 293ms/step - loss: 0.4787 - mean_squared_error: 0.0523 - val_loss: 1.0715 - val_mean_squared_error: 0.1438 - lr: 7.4082e-04
# Epoch 128/500
# 8/8 [==============================] - ETA: 0s - loss: 0.5657 - mean_squared_error: 0.0688
# Epoch 128: saving model to checkpoints/cp-0128.ckpt
# 8/8 [==============================] - 2s 306ms/step - loss: 0.5657 - mean_squared_error: 0.0688 - val_loss: 1.0939 - val_mean_squared_error: 0.1552 - lr: 7.4082e-04
# Epoch 129/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4177 - mean_squared_error: 0.0393
# Epoch 129: saving model to checkpoints/cp-0129.ckpt
# 8/8 [==============================] - 3s 338ms/step - loss: 0.4177 - mean_squared_error: 0.0393 - val_loss: 0.9995 - val_mean_squared_error: 0.1439 - lr: 7.4082e-04
# Epoch 130/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4670 - mean_squared_error: 0.0481
# Epoch 130: saving model to checkpoints/cp-0130.ckpt
# 8/8 [==============================] - 2s 325ms/step - loss: 0.4670 - mean_squared_error: 0.0481 - val_loss: 1.2840 - val_mean_squared_error: 0.2031 - lr: 7.4082e-04
# Epoch 131/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4780 - mean_squared_error: 0.0443
# Epoch 131: saving model to checkpoints/cp-0131.ckpt
# 8/8 [==============================] - 2s 310ms/step - loss: 0.4780 - mean_squared_error: 0.0443 - val_loss: 1.2704 - val_mean_squared_error: 0.1960 - lr: 6.7032e-04
# Epoch 132/500
# 8/8 [==============================] - ETA: 0s - loss: 0.5151 - mean_squared_error: 0.0501
# Epoch 132: saving model to checkpoints/cp-0132.ckpt
# 8/8 [==============================] - 2s 323ms/step - loss: 0.5151 - mean_squared_error: 0.0501 - val_loss: 0.9044 - val_mean_squared_error: 0.1215 - lr: 6.7032e-04
# Epoch 133/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4376 - mean_squared_error: 0.0396
# Epoch 133: saving model to checkpoints/cp-0133.ckpt
# 8/8 [==============================] - 3s 347ms/step - loss: 0.4376 - mean_squared_error: 0.0396 - val_loss: 1.1869 - val_mean_squared_error: 0.1722 - lr: 6.7032e-04
# Epoch 134/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4242 - mean_squared_error: 0.0385
# Epoch 134: saving model to checkpoints/cp-0134.ckpt
# 8/8 [==============================] - 2s 323ms/step - loss: 0.4242 - mean_squared_error: 0.0385 - val_loss: 0.7866 - val_mean_squared_error: 0.0939 - lr: 6.7032e-04
# Epoch 135/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4853 - mean_squared_error: 0.0506
# Epoch 135: saving model to checkpoints/cp-0135.ckpt
# 8/8 [==============================] - 2s 328ms/step - loss: 0.4853 - mean_squared_error: 0.0506 - val_loss: 0.9032 - val_mean_squared_error: 0.1250 - lr: 6.7032e-04
# Epoch 136/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4773 - mean_squared_error: 0.0521
# Epoch 136: saving model to checkpoints/cp-0136.ckpt
# 8/8 [==============================] - 2s 321ms/step - loss: 0.4773 - mean_squared_error: 0.0521 - val_loss: 0.7654 - val_mean_squared_error: 0.1011 - lr: 6.7032e-04
# Epoch 137/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3975 - mean_squared_error: 0.0393
# Epoch 137: saving model to checkpoints/cp-0137.ckpt
# 8/8 [==============================] - 3s 349ms/step - loss: 0.3975 - mean_squared_error: 0.0393 - val_loss: 0.8116 - val_mean_squared_error: 0.1090 - lr: 6.7032e-04
# Epoch 138/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4093 - mean_squared_error: 0.0445
# Epoch 138: saving model to checkpoints/cp-0138.ckpt
# 8/8 [==============================] - 3s 372ms/step - loss: 0.4093 - mean_squared_error: 0.0445 - val_loss: 0.8268 - val_mean_squared_error: 0.1072 - lr: 6.7032e-04
# Epoch 139/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3607 - mean_squared_error: 0.0350
# Epoch 139: saving model to checkpoints/cp-0139.ckpt
# 8/8 [==============================] - 2s 311ms/step - loss: 0.3607 - mean_squared_error: 0.0350 - val_loss: 0.8651 - val_mean_squared_error: 0.1200 - lr: 6.7032e-04
# Epoch 140/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4054 - mean_squared_error: 0.0443
# Epoch 140: saving model to checkpoints/cp-0140.ckpt
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4054 - mean_squared_error: 0.0443 - val_loss: 0.8894 - val_mean_squared_error: 0.1267 - lr: 6.7032e-04
# Epoch 141/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3625 - mean_squared_error: 0.0358
# Epoch 141: saving model to checkpoints/cp-0141.ckpt
# 8/8 [==============================] - 2s 294ms/step - loss: 0.3625 - mean_squared_error: 0.0358 - val_loss: 0.8495 - val_mean_squared_error: 0.1170 - lr: 6.0653e-04
# Epoch 142/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3872 - mean_squared_error: 0.0407
# Epoch 142: saving model to checkpoints/cp-0142.ckpt
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3872 - mean_squared_error: 0.0407 - val_loss: 0.8364 - val_mean_squared_error: 0.1137 - lr: 6.0653e-04
# Epoch 143/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3896 - mean_squared_error: 0.0408
# Epoch 143: saving model to checkpoints/cp-0143.ckpt
# 8/8 [==============================] - 2s 327ms/step - loss: 0.3896 - mean_squared_error: 0.0408 - val_loss: 1.0924 - val_mean_squared_error: 0.1454 - lr: 6.0653e-04
# Epoch 144/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4018 - mean_squared_error: 0.0437
# Epoch 144: saving model to checkpoints/cp-0144.ckpt
# 8/8 [==============================] - 2s 322ms/step - loss: 0.4018 - mean_squared_error: 0.0437 - val_loss: 1.1537 - val_mean_squared_error: 0.1607 - lr: 6.0653e-04
# Epoch 145/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3796 - mean_squared_error: 0.0392
# Epoch 145: saving model to checkpoints/cp-0145.ckpt
# 8/8 [==============================] - 2s 334ms/step - loss: 0.3796 - mean_squared_error: 0.0392 - val_loss: 0.9137 - val_mean_squared_error: 0.1073 - lr: 6.0653e-04
# Epoch 146/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3732 - mean_squared_error: 0.0374
# Epoch 146: saving model to checkpoints/cp-0146.ckpt
# 8/8 [==============================] - 2s 321ms/step - loss: 0.3732 - mean_squared_error: 0.0374 - val_loss: 0.7830 - val_mean_squared_error: 0.0937 - lr: 6.0653e-04
# Epoch 147/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3716 - mean_squared_error: 0.0346
# Epoch 147: saving model to checkpoints/cp-0147.ckpt
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3716 - mean_squared_error: 0.0346 - val_loss: 1.0718 - val_mean_squared_error: 0.1620 - lr: 6.0653e-04
# Epoch 148/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4023 - mean_squared_error: 0.0380
# Epoch 148: saving model to checkpoints/cp-0148.ckpt
# 8/8 [==============================] - 2s 316ms/step - loss: 0.4023 - mean_squared_error: 0.0380 - val_loss: 0.7579 - val_mean_squared_error: 0.0848 - lr: 6.0653e-04
# Epoch 149/500
# 8/8 [==============================] - ETA: 0s - loss: 0.
500
# 8/8 [==============================] - ETA: 0s - loss: 0.3437 - mean_squared_error: 0.0395
# Epoch 461: saving model to checkpoints/cp-0461.ckpt
# 8/8 [==============================] - 3s 358ms/step - loss: 0.3437 - mean_squared_error: 0.0395 - val_loss: 0.4357 - val_mean_squared_error: 0.0592 - lr: 2.4724e-05
# Epoch 462/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3677 - mean_squared_error: 0.0442
# Epoch 462: saving model to checkpoints/cp-0462.ckpt
# 8/8 [==============================] - 3s 328ms/step - loss: 0.3677 - mean_squared_error: 0.0442 - val_loss: 0.4307 - val_mean_squared_error: 0.0580 - lr: 2.4724e-05
# Epoch 463/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3307 - mean_squared_error: 0.0378
# Epoch 463: saving model to checkpoints/cp-0463.ckpt
# 8/8 [==============================] - 3s 384ms/step - loss: 0.3307 - mean_squared_error: 0.0378 - val_loss: 0.4086 - val_mean_squared_error: 0.0537 - lr: 2.4724e-05
# Epoch 464/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3803 - mean_squared_error: 0.0488
# Epoch 464: saving model to checkpoints/cp-0464.ckpt
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3803 - mean_squared_error: 0.0488 - val_loss: 0.4154 - val_mean_squared_error: 0.0546 - lr: 2.4724e-05
# Epoch 465/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3607 - mean_squared_error: 0.0439
# Epoch 465: saving model to checkpoints/cp-0465.ckpt
# 8/8 [==============================] - 2s 300ms/step - loss: 0.3607 - mean_squared_error: 0.0439 - val_loss: 0.4189 - val_mean_squared_error: 0.0553 - lr: 2.4724e-05
# Epoch 466/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4249 - mean_squared_error: 0.0544
# Epoch 466: saving model to checkpoints/cp-0466.ckpt
# 8/8 [==============================] - 2s 294ms/step - loss: 0.4249 - mean_squared_error: 0.0544 - val_loss: 0.4158 - val_mean_squared_error: 0.0551 - lr: 2.4724e-05
# Epoch 467/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3550 - mean_squared_error: 0.0420
# Epoch 467: saving model to checkpoints/cp-0467.ckpt
# 8/8 [==============================] - 2s 301ms/step - loss: 0.3550 - mean_squared_error: 0.0420 - val_loss: 0.4479 - val_mean_squared_error: 0.0616 - lr: 2.4724e-05
# Epoch 468/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4198 - mean_squared_error: 0.0544
# Epoch 468: saving model to checkpoints/cp-0468.ckpt
# 8/8 [==============================] - 2s 299ms/step - loss: 0.4198 - mean_squared_error: 0.0544 - val_loss: 0.4412 - val_mean_squared_error: 0.0605 - lr: 2.4724e-05
# Epoch 469/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3640 - mean_squared_error: 0.0434
# Epoch 469: saving model to checkpoints/cp-0469.ckpt
# 8/8 [==============================] - 2s 320ms/step - loss: 0.3640 - mean_squared_error: 0.0434 - val_loss: 0.4424 - val_mean_squared_error: 0.0604 - lr: 2.4724e-05
# Epoch 470/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3288 - mean_squared_error: 0.0347
# Epoch 470: saving model to checkpoints/cp-0470.ckpt
# 8/8 [==============================] - 2s 284ms/step - loss: 0.3288 - mean_squared_error: 0.0347 - val_loss: 0.4528 - val_mean_squared_error: 0.0619 - lr: 2.4724e-05
# Epoch 471/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3431 - mean_squared_error: 0.0390
# Epoch 471: saving model to checkpoints/cp-0471.ckpt
# 8/8 [==============================] - 2s 285ms/step - loss: 0.3431 - mean_squared_error: 0.0390 - val_loss: 0.4558 - val_mean_squared_error: 0.0625 - lr: 2.2371e-05
# Epoch 472/500
# 8/8 [==============================] - ETA: 0s - loss: 0.
500
# 8/8 [==============================] - ETA: 0s - loss: 0.3966 - mean_squared_error: 0.0504
# Epoch 483: saving model to checkpoints/cp-0483.ckpt
# 8/8 [==============================] - 2s 318ms/step - loss: 0.3966 - mean_squared_error: 0.0504 - val_loss: 0.4096 - val_mean_squared_error: 0.0539 - lr: 2.0242e-05
# Epoch 484/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3997 - mean_squared_error: 0.0516
# Epoch 484: saving model to checkpoints/cp-0484.ckpt
# 8/8 [==============================] - 2s 290ms/step - loss: 0.3997 - mean_squared_error: 0.0516 - val_loss: 0.3961 - val_mean_squared_error: 0.0506 - lr: 2.0242e-05
# Epoch 485/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3313 - mean_squared_error: 0.0386
# Epoch 485: saving model to checkpoints/cp-0485.ckpt
# 8/8 [==============================] - 2s 287ms/step - loss: 0.3313 - mean_squared_error: 0.0386 - val_loss: 0.3967 - val_mean_squared_error: 0.0502 - lr: 2.0242e-05
# Epoch 486/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3779 - mean_squared_error: 0.0451
# Epoch 486: saving model to checkpoints/cp-0486.ckpt
# 8/8 [==============================] - 2s 305ms/step - loss: 0.3779 - mean_squared_error: 0.0451 - val_loss: 0.4779 - val_mean_squared_error: 0.0653 - lr: 2.0242e-05
# Epoch 487/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3664 - mean_squared_error: 0.0444
# Epoch 487: saving model to checkpoints/cp-0487.ckpt
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3664 - mean_squared_error: 0.0444 - val_loss: 0.4882 - val_mean_squared_error: 0.0681 - lr: 2.0242e-05
# Epoch 488/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3918 - mean_squared_error: 0.0498
# Epoch 488: saving model to checkpoints/cp-0488.ckpt
# 8/8 [==============================] - 2s 287ms/step - loss: 0.3918 - mean_squared_error: 0.0498 - val_loss: 0.4815 - val_mean_squared_error: 0.0670 - lr: 2.0242e-05
# Epoch 489/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3952 - mean_squared_error: 0.0500
# Epoch 489: saving model to checkpoints/cp-0489.ckpt
# 8/8 [==============================] - 2s 283ms/step - loss: 0.3952 - mean_squared_error: 0.0500 - val_loss: 0.4723 - val_mean_squared_error: 0.0659 - lr: 2.0242e-05
# Epoch 490/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3797 - mean_squared_error: 0.0465
# Epoch 490: saving model to checkpoints/cp-0490.ckpt
# 8/8 [==============================] - 2s 288ms/step - loss: 0.3797 - mean_squared_error: 0.0465 - val_loss: 0.4623 - val_mean_squared_error: 0.0640 - lr: 2.0242e-05
# Epoch 491/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3133 - mean_squared_error: 0.0341
# Epoch 491: saving model to checkpoints/cp-0491.ckpt
# 8/8 [==============================] - 2s 284ms/step - loss: 0.3133 - mean_squared_error: 0.0341 - val_loss: 0.4527 - val_mean_squared_error: 0.0622 - lr: 1.8316e-05
# Epoch 492/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3875 - mean_squared_error: 0.0483
# Epoch 492: saving model to checkpoints/cp-0492.ckpt
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3875 - mean_squared_error: 0.0483 - val_loss: 0.4596 - val_mean_squared_error: 0.0630 - lr: 1.8316e-05
# Epoch 493/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3203 - mean_squared_error: 0.0357
# Epoch 493: saving model to checkpoints/cp-0493.ckpt
# 8/8 [==============================] - 2s 302ms/step - loss: 0.3203 - mean_squared_error: 0.0357 - val_loss: 0.4614 - val_mean_squared_error: 0.0633 - lr: 1.8316e-05
# Epoch 494/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3586 - mean_squared_error: 0.0424
# Epoch 494: saving model to checkpoints/cp-0494.ckpt
# 8/8 [==============================] - 2s 293ms/step - loss: 0.3586 - mean_squared_error: 0.0424 - val_loss: 0.4496 - val_mean_squared_error: 0.0620 - lr: 1.8316e-05
# Epoch 495/500
# 8/8 [==============================] - ETA: 0s - loss: 0.4593 - mean_squared_error: 0.0629
# Epoch 495: saving model to checkpoints/cp-0495.ckpt
# 8/8 [==============================] - 2s 287ms/step - loss: 0.4593 - mean_squared_error: 0.0629 - val_loss: 0.4351 - val_mean_squared_error: 0.0593 - lr: 1.8316e-05
# Epoch 496/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3128 - mean_squared_error: 0.0341
# Epoch 496: saving model to checkpoints/cp-0496.ckpt
# 8/8 [==============================] - 2s 285ms/step - loss: 0.3128 - mean_squared_error: 0.0341 - val_loss: 0.4340 - val_mean_squared_error: 0.0589 - lr: 1.8316e-05
# Epoch 497/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3014 - mean_squared_error: 0.0312
# Epoch 497: saving model to checkpoints/cp-0497.ckpt
# 8/8 [==============================] - 2s 293ms/step - loss: 0.3014 - mean_squared_error: 0.0312 - val_loss: 0.4315 - val_mean_squared_error: 0.0585 - lr: 1.8316e-05
# Epoch 498/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3446 - mean_squared_error: 0.0406
# Epoch 498: saving model to checkpoints/cp-0498.ckpt
# 8/8 [==============================] - 2s 320ms/step - loss: 0.3446 - mean_squared_error: 0.0406 - val_loss: 0.4344 - val_mean_squared_error: 0.0588 - lr: 1.8316e-05
# Epoch 499/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3142 - mean_squared_error: 0.0349
# Epoch 499: saving model to checkpoints/cp-0499.ckpt
# 8/8 [==============================] - 3s 371ms/step - loss: 0.3142 - mean_squared_error: 0.0349 - val_loss: 0.4360 - val_mean_squared_error: 0.0589 - lr: 1.8316e-05
# Epoch 500/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3856 - mean_squared_error: 0.0476
# Epoch 500: saving model to checkpoints/cp-0500.ckpt
# 8/8 [==============================] - 3s 447ms/step - loss: 0.3856 - mean_squared_error: 0.0476 - val_loss: 0.4168 - val_mean_squared_error: 0.0552 - lr: 1.8316e-05
# 2/2 [==============================] - 0s 72ms/step - loss: 0.4168 - mean_squared_error: 0.0552

# %%
import pandas as pd
# Convert the results to a DataFrame and save to a CSV file
results_df = pd.DataFrame(results)
results_df.to_csv('cross_validation_results.csv', index=False)

print("Cross-validation results saved to 'cross_validation_results.csv'")
# Out:
# Cross-validation results saved to 'cross_validation_results.csv'

# %%
def load_model_for_fold(fold_n):
    """
    Load the model for a specific fold.

    Args:
    fold_n: The fold number for which to load the model.

    Returns:
    The loaded model.
    """
    model_path = f'model_fold_{fold_n}.h5'
    return tf.keras.models.load_model(model_path, custom_objects={'smooth_l1_loss_fixed': smooth_l1_loss()})

def get_validation_data_for_fold(fold_n, images, boxes, kf):
    """
    Get the validation data for a specific fold.

    Args:
    fold_n: The fold number for which to get the validation data.
    images: The full images dataset.
    boxes: The full boxes dataset.
    kf: The KFold object used for splitting.

    Returns:
    A tuple of (validation_images, validation_boxes).
    """
    for i, (train_index, val_index) in enumerate(kf.split(images)):
        if i == fold_n - 1:  # fold_n is 1-indexed
            return images[val_index], [boxes[j] for j in val_index]
    raise ValueError(f"Fold {fold_n} not found")

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

def plot_image_with_boxes(image, true_boxes, pred_boxes, figsize=(10, 10)):
    """
    Plots an image with overlaid true and predicted bounding boxes, ensuring visibility even when boxes overlap.
    
    Args:
    image: The image as a NumPy array, normalized between [-1, 1].
    true_boxes: A NumPy array of true bounding boxes of shape (N, 4), where N is the number of boxes,
                and each box is defined as (ymin, xmin, ymax, xmax).
    pred_boxes: A NumPy array of predicted bounding boxes of shape (N, 4), similar to true_boxes.
    figsize: Size of the figure to display.
    """
    # Rescale the image from [-1,1] to [0,1] for displaying
    image = (image + 1) / 2.0

    fig, ax = plt.subplots(1, figsize=figsize)
    ax.imshow(image)  # If the image is not grayscale, remove cmap='gray'

    img_height, img_width = image.shape[:2]
    
    # Plot true bounding boxes
    for box in true_boxes:
        if np.all(box == 0):
            continue  # Skip boxes that are all zeros (used for padding)
        ymin, xmin, ymax, xmax = box
        ymin *= img_height
        ymax *= img_height
        xmin *= img_width
        xmax *= img_width
        # Use a solid line for true boxes
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=2, edgecolor='limegreen', facecolor='none', linestyle='-', label='True')
        ax.add_patch(rect)
    
    # Plot predicted bounding boxes
    for box in pred_boxes:
        if np.all(box == 0):
            continue  # Skip boxes that are all zeros (used for padding)
        ymin, xmin, ymax, xmax = box
        ymin *= img_height
        ymax *= img_height
        xmin *= img_width
        xmax *= img_width
        # Use a dashed line for predicted boxes
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=2, edgecolor='red', facecolor='none', linestyle='--', alpha=1, label='Pred')
        ax.add_patch(rect)

    # Create a legend
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    # This ensures that only one label for each line style is added to the legend
    unique_labels = list(set(labels))
    unique_handles = [by_label[label] for label in unique_labels]
    ax.legend(unique_handles, unique_labels)
    
    plt.show()

# %%
# Example usage
fold_n = 9  # Specify the fold number
model = load_model_for_fold(fold_n)

# Assuming 'kf' is your KFold object and 'images', 'boxes' are your full datasets
val_images, val_boxes = get_validation_data_for_fold(fold_n, images, boxes, kf)

# Select an index of an image to display from the validation set
image_index = 0
selected_image = val_images[image_index]
selected_true_boxes = pad_labels([val_boxes[image_index]])

# Predict the bounding boxes for the selected image
pred_boxes = model.predict(selected_image[np.newaxis, ...])

# Plot the image with true and predicted boxes
plot_image_with_boxes(selected_image, selected_true_boxes[0], pred_boxes[0])
# Out:
# 1/1 [==============================] - 0s 398ms/step

# %%
image = 2 # Select an index of an image to display

pred_boxes = model.predict(images[image:image+1])  # Predict the bounding boxes for the 11th image
# Rescale predictions if necessary here

true_boxes = pad_labels(boxes)


plot_image_with_boxes(images[image], true_boxes[image], pred_boxes[0])
# Out:
# 1/1 [==============================] - 0s 74ms/step
