# %%
import tensorflow as tf
import numpy as np
import json
import os
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Function to resize labels
def resize_labels(labels, original_size, new_size):
    # Adjust the label coordinates for the new image size
    scale_x = new_size[1] / original_size[1]
    scale_y = new_size[0] / original_size[0]
    resized_labels = []
    for label in labels:
        resized_label = {
            'x': label['x'] * scale_x,
            'y': label['y'] * scale_y,
            'radius': label['radius'] * scale_x  # Assuming uniform scaling in x and y
        }
        resized_labels.append(resized_label)
    return resized_labels


# Function to convert labels to EfficientDet format
def convert_to_efficientdet_format(labels, image_shape):
    efficientdet_labels = []
    for label in labels:
        # Calculate the coordinates of the upper left and lower right corners
        xmin = (label['x'] - label['radius']) / image_shape[1]
        ymin = (label['y'] - label['radius']) / image_shape[0]
        xmax = (label['x'] + label['radius']) / image_shape[1]
        ymax = (label['y'] + label['radius']) / image_shape[0]
        # EfficientDet format [ymin, xmin, ymax, xmax]
        efficientdet_labels.append([
            max(0, ymin), max(0, xmin), min(1, ymax), min(1, xmax)
        ])
    return efficientdet_labels


# Function to load images and labels
def load_images_and_labels(image_dir, label_dir, original_size=(1024, 1024), new_size=(512, 512)):
    image_files = [os.path.join(image_dir, file) for file in sorted(os.listdir(image_dir)) if file.endswith('.png')]
    label_files = [os.path.join(label_dir, file) for file in sorted(os.listdir(label_dir)) if file.endswith('.json')]
    
    images = []
    all_boxes = []

    for image_file, label_file in zip(image_files, label_files):
        # Load and resize image
        image = load_img(image_file, color_mode='rgb', target_size=new_size)
        # Convert the image to an array and scale the pixel values to [-1, 1]
        image = (img_to_array(image) / 127.5) - 1
        images.append(image)

        # Load labels and adjust for new image size
        with open(label_file, 'r') as file:
            json_data = json.load(file)
        resized_json_data = resize_labels(json_data, original_size=original_size, new_size=new_size)
        boxes = convert_to_efficientdet_format(resized_json_data, new_size)
        all_boxes.append(boxes)
    
    return np.array(images), all_boxes


# Function to pad labels to a fixed size
def pad_labels(labels, max_boxes=250, pad_value=0):
    padded_labels = []
    for label in labels:
        padded_label = np.zeros((max_boxes, 4), dtype=np.float32) + pad_value
        num_boxes = min(len(label), max_boxes)
        padded_label[:num_boxes] = label[:num_boxes]
        padded_labels.append(padded_label)
    return np.array(padded_labels)

# Function to prepare the dataset
def prepare_dataset(images, boxes, batch_size, num_boxes=250):
    images = tf.constant(images, dtype=tf.float32)
    boxes = pad_labels(boxes, max_boxes=num_boxes)
    boxes = tf.constant(boxes, dtype=tf.float32)

    dataset = tf.data.Dataset.from_tensor_slices((images, boxes))
    dataset = dataset.shuffle(len(images)).batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
batch_size = 2
image_dir = './TMA_WSI_Padded_PNGs'
label_dir = './TMA_WSI_Labels_updated'
images, boxes = load_images_and_labels(image_dir, label_dir)
# Map this preprocessing function to your dataset


# Assuming we have only one class for object detection and 100 boxes per image
num_boxes = 250  # Maximum number of boxes per image, adjust as needed

dataset = prepare_dataset(images, boxes, batch_size, num_boxes=num_boxes)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def plot_image_with_boxes(image, boxes, figsize=(10, 10)):
    """
    Plots an image with overlaid bounding boxes.

    Args:
    image: The image as a NumPy array.
    boxes: A NumPy array of bounding boxes of shape (N, 4), where N is the number of boxes,
           and each box is defined as (ymin, xmin, ymax, xmax).
    figsize: Size of the figure to display.
    """
    fig, ax = plt.subplots(1, figsize=figsize)
    ax.imshow(image, cmap='gray')  # Assuming the image is grayscale, adjust colormap if not

    img_height, img_width = image.shape[:2]
    for box in boxes:
        if np.all(box == 0):
            continue  # Skip boxes that are all zeros (used for padding)
        ymin, xmin, ymax, xmax = box
        ymin *= img_height
        ymax *= img_height
        xmin *= img_width
        xmax *= img_width
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=2, edgecolor='r', facecolor='none')
        ax.add_patch(rect)

    plt.show()

# Example usage:
# Assuming `images` is your array of images loaded from the dataset and
# `boxes` is the array of bounding boxes for the corresponding images.
# Here we visualize the first image and its boxes.
plot_image_with_boxes(images[10], boxes[10])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
def create_object_detection_model(num_boxes):
    backbone = tf.keras.applications.MobileNetV2(input_shape=[512, 512, 3], include_top=False, weights='imagenet')
    backbone.trainable = False

    x = backbone.output
    x = layers.Conv2D(256, kernel_size=(3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(128, kernel_size=(3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu', padding='same')(x)
    x = layers.GlobalAveragePooling2D()(x)

    # Output layer for bounding box predictions
    # The output is reshaped to [batch_size, num_boxes, 4]
    boxes_output_flat = layers.Dense(num_boxes * 4, activation='sigmoid', name='boxes_output')(x)
    boxes_output = layers.Reshape((num_boxes, 4))(boxes_output_flat)

    model = models.Model(inputs=backbone.input, outputs=boxes_output)
    
    return model


model = create_object_detection_model(num_boxes)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  Conv1 (Conv2D)              (None, 256, 256, 32)         864       ['input_2[0][0]']
#
#  bn_Conv1 (BatchNormalizati  (None, 256, 256, 32)         128       ['Conv1[0][0]']
#  on)
#
#  Conv1_relu (ReLU)           (None, 256, 256, 32)         0         ['bn_Conv1[0][0]']
#
#  expanded_conv_depthwise (D  (None, 256, 256, 32)         288       ['Conv1_relu[0][0]']
#  epthwiseConv2D)
#
#  expanded_conv_depthwise_BN  (None, 256, 256, 32)         128       ['expanded_conv_depthwise[0][0
#   (BatchNormalization)                                              ]']
#
#  expanded_conv_depthwise_re  (None, 256, 256, 32)         0         ['expanded_conv_depthwise_BN[0
#  lu (ReLU)                                                          ][0]']
#
#  expanded_conv_project (Con  (None, 256, 256, 16)         512       ['expanded_conv_depthwise_relu
#  v2D)                                                               [0][0]']
#
#  expanded_conv_project_BN (  (None, 256, 256, 16)         64        ['expanded_conv_project[0][0]'
#  BatchNormalization)                                                ]
#
#  block_1_expand (Conv2D)     (None, 256, 256, 96)         1536      ['expanded_conv_project_BN[0][
#                                                                     0]']
#
#  block_1_expand_BN (BatchNo  (None, 256, 256, 96)         384       ['block_1_expand[0][0]']
#  rmalization)
#
#  block_1_expand_relu (ReLU)  (None, 256, 256, 96)         0         ['block_1_expand_BN[0][0]']
#
#  block_1_pad (ZeroPadding2D  (None, 257, 257, 96)         0         ['block_1_expand_relu[0][0]']
#  )
#
#  block_1_depthwise (Depthwi  (None, 128, 128, 96)         864       ['block_1_pad[0][0]']
#  seConv2D)
#
#  block_1_depthwise_BN (Batc  (None, 128, 128, 96)         384       ['block_1_depthwise[0][0]']
#  hNormalization)
#
#  block_1_depthwise_relu (Re  (None, 128, 128, 96)         0         ['block_1_depthwise_BN[0][0]']
#  LU)
#
#  block_1_project (Conv2D)    (None, 128, 128, 24)         2304      ['block_1_depthwise_relu[0][0]
#                                                                     ']
#
#  block_1_project_BN (BatchN  (None, 128, 128, 24)         96        ['block_1_project[0][0]']
#  ormalization)
#
#  block_2_expand (Conv2D)     (None, 128, 128, 144)        3456      ['block_1_project_BN[0][0]']
#
#  block_2_expand_BN (BatchNo  (None, 128, 128, 144)        576       ['block_2_expand[0][0]']
#  rmalization)
#
#  block_2_expand_relu (ReLU)  (None, 128, 128, 144)        0         ['block_2_expand_BN[0][0]']
#
#  block_2_depthwise (Depthwi  (None, 128, 128, 144)        1296      ['block_2_expand_relu[0][0]']
#  seConv2D)
#
#  block_2_depthwise_BN (Batc  (None, 128, 128, 144)        576       ['block_2_depthwise[0][0]']
#  hNormalization)
#
#  block_2_depthwise_relu (Re  (None, 128, 128, 144)        0         ['block_2_depthwise_BN[0][0]']
#  LU)
#
#  block_2_project (Conv2D)    (None, 128, 128, 24)         3456      ['block_2_depthwise_relu[0][0]
#                                                                     ']
#
#  block_2_project_BN (BatchN  (None, 128, 128, 24)         96        ['block_2_project[0][0]']
#  ormalization)
#
#  block_2_add (Add)           (None, 128, 128, 24)         0         ['block_1_project_BN[0][0]',
#                                                                      'block_2_project_BN[0][0]']
#
#  block_3_expand (Conv2D)     (None, 128, 128, 144)        3456      ['block_2_add[0][0]']
#
#  block_3_expand_BN (BatchNo  (None, 128, 128, 144)        576       ['block_3_expand[0][0]']
#  rmalization)
#
#  block_3_expand_relu (ReLU)  (None, 128, 128, 144)        0         ['block_3_expand_BN[0][0]']
#
#  block_3_pad (ZeroPadding2D  (None, 129, 129, 144)        0         ['block_3_expand_relu[0][0]']
#  )
#
#  block_3_depthwise (Depthwi  (None, 64, 64, 144)          1296      ['block_3_pad[0][0]']
#  seConv2D)
#
#  block_3_depthwise_BN (Batc  (None, 64, 64, 144)          576       ['block_3_depthwise[0][0]']
#  hNormalization)
#
#  block_3_depthwise_relu (Re  (None, 64, 64, 144)          0         ['block_3_depthwise_BN[0][0]']
#  LU)
#
#  block_3_project (Conv2D)    (None, 64, 64, 32)           4608      ['block_3_depthwise_relu[0][0]
#                                                                     ']
#
#  block_3_project_BN (BatchN  (None, 64, 64, 32)           128       ['block_3_project[0][0]']
#  ormalization)
#
#  block_4_expand (Conv2D)     (None, 64, 64, 192)          6144      ['block_3_project_BN[0][0]']
#
#  block_4_expand_BN (BatchNo  (None, 64, 64, 192)          768       ['block_4_expand[0][0]']
#  rmalization)
#
#  block_4_expand_relu (ReLU)  (None, 64, 64, 192)          0         ['block_4_expand_BN[0][0]']
#
#  block_4_depthwise (Depthwi  (None, 64, 64, 192)          1728      ['block_4_expand_relu[0][0]']
#  seConv2D)
#
#  block_4_depthwise_BN (Batc  (None, 64, 64, 192)          768       ['block_4_depthwise[0][0]']
#  hNormalization)
#
#  block_4_depthwise_relu (Re  (None, 64, 64, 192)          0         ['block_4_depthwise_BN[0][0]']
#  LU)
#
#  block_4_project (Conv2D)    (None, 64, 64, 32)           6144      ['block_4_depthwise_relu[0][0]
#                                                                     ']
#
#  block_4_project_BN (BatchN  (None, 64, 64, 32)           128       ['block_4_project[0][0]']
#  ormalization)
#
#  block_4_add (Add)           (None, 64, 64, 32)           0         ['block_3_project_BN[0][0]',
#                                                                      'block_4_project_BN[0][0]']
#
#  block_5_expand (Conv2D)     (None, 64, 64, 192)          6144      ['block_4_add[0][0]']
#
#  block_5_expand_BN (BatchNo  (None, 64, 64, 192)          768       ['block_5_expand[0][0]']
#  rmalization)
#
#  block_5_expand_relu (ReLU)  (None, 64, 64, 192)          0         ['block_5_expand_BN[0][0]']
#
#  block_5_depthwise (Depthwi  (None, 64, 64, 192)          1728      ['block_5_expand_relu[0][0]']
#  seConv2D)
#
#  block_5_depthwise_BN (Batc  (None, 64, 64, 192)          768       ['block_5_depthwise[0][0]']
#  hNormalization)
#
#  block_5_depthwise_relu (Re  (None, 64, 64, 192)          0         ['block_5_depthwise_BN[0][0]']
#  LU)
#
#  block_5_project (Conv2D)    (None, 64, 64, 32)           6144      ['block_5_depthwise_relu[0][0]
#                                                                     ']
#
#  block_5_project_BN (BatchN  (None, 64, 64, 32)           128       ['block_5_project[0][0]']
#  ormalization)
#
#  block_5_add (Add)           (None, 64, 64, 32)           0         ['block_4_add[0][0]',
#                                                                      'block_5_project_BN[0][0]']
#
#  block_6_expand (Conv2D)     (None, 64, 64, 192)          6144      ['block_5_add[0][0]']
#
#  block_6_expand_BN (BatchNo  (None, 64, 64, 192)          768       ['block_6_expand[0][0]']
#  rmalization)
#
#  block_6_expand_relu (ReLU)  (None, 64, 64, 192)          0         ['block_6_expand_BN[0][0]']
#
#  block_6_pad (ZeroPadding2D  (None, 65, 65, 192)          0         ['block_6_expand_relu[0][0]']
#  )
#
#  block_6_depthwise (Depthwi  (None, 32, 32, 192)          1728      ['block_6_pad[0][0]']
#  seConv2D)
#
#  block_6_depthwise_BN (Batc  (None, 32, 32, 192)          768       ['block_6_depthwise[0][0]']
#  hNormalization)
#
#  block_6_depthwise_relu (Re  (None, 32, 32, 192)          0         ['block_6_depthwise_BN[0][0]']
#  LU)
#
#  block_6_project (Conv2D)    (None, 32, 32, 64)           12288     ['block_6_depthwise_relu[0][0]
#                                                                     ']
#
#  block_6_project_BN (BatchN  (None, 32, 32, 64)           256       ['block_6_project[0][0]']
#  ormalization)
#
#  block_7_expand (Conv2D)     (None, 32, 32, 384)          24576     ['block_6_project_BN[0][0]']
#
#  block_7_expand_BN (BatchNo  (None, 32, 32, 384)          1536      ['block_7_expand[0][0]']
#  rmalization)
#
#  block_7_expand_relu (ReLU)  (None, 32, 32, 384)          0         ['block_7_expand_BN[0][0]']
#
#  block_7_depthwise (Depthwi  (None, 32, 32, 384)          3456      ['block_7_expand_relu[0][0]']
#  seConv2D)
#
#  block_7_depthwise_BN (Batc  (None, 32, 32, 384)          1536      ['block_7_depthwise[0][0]']
#  hNormalization)
#
#  block_7_depthwise_relu (Re  (None, 32, 32, 384)          0         ['block_7_depthwise_BN[0][0]']
#  LU)
#
#  block_7_project (Conv2D)    (None, 32, 32, 64)           24576     ['block_7_depthwise_relu[0][0]
#                                                                     ']
#
#  block_7_project_BN (BatchN  (None, 32, 32, 64)           256       ['block_7_project[0][0]']
#  ormalization)
#
#  block_7_add (Add)           (None, 32, 32, 64)           0         ['block_6_project_BN[0][0]',
#                                                                      'block_7_project_BN[0][0]']
#
#  block_8_expand (Conv2D)     (None, 32, 32, 384)          24576     ['block_7_add[0][0]']
#
#  block_8_expand_BN (BatchNo  (None, 32, 32, 384)          1536      ['block_8_expand[0][0]']
#  rmalization)
#
#  block_8_expand_relu (ReLU)  (None, 32, 32, 384)          0         ['block_8_expand_BN[0][0]']
#
#  block_8_depthwise (Depthwi  (None, 32, 32, 384)          3456      ['block_8_expand_relu[0][0]']
#  seConv2D)
#
#  block_8_depthwise_BN (Batc  (None, 32, 32, 384)          1536      ['block_8_depthwise[0][0]']
#  hNormalization)
#
#  block_8_depthwise_relu (Re  (None, 32, 32, 384)          0         ['block_8_depthwise_BN[0][0]']
#  LU)
#
#  block_8_project (Conv2D)    (None, 32, 32, 64)           24576     ['block_8_depthwise_relu[0][0]
#                                                                     ']
#
#  block_8_project_BN (BatchN  (None, 32, 32, 64)           256       ['block_8_project[0][0]']
#  ormalization)
#
#  block_8_add (Add)           (None, 32, 32, 64)           0         ['block_7_add[0][0]',
#                                                                      'block_8_project_BN[0][0]']
#
#  block_9_expand (Conv2D)     (None, 32, 32, 384)          24576     ['block_8_add[0][0]']
#
#  block_9_expand_BN (BatchNo  (None, 32, 32, 384)          1536      ['block_9_expand[0][0]']
#  rmalization)
#
#  block_9_expand_relu (ReLU)  (None, 32, 32, 384)          0         ['block_9_expand_BN[0][0]']
#
#  block_9_depthwise (Depthwi  (None, 32, 32, 384)          3456      ['block_9_expand_relu[0][0]']
#  seConv2D)
#
#  block_9_depthwise_BN (Batc  (None, 32, 32, 384)          1536      ['block_9_depthwise[0][0]']
#  hNormalization)
#
#  block_9_depthwise_relu (Re  (None, 32, 32, 384)          0         ['block_9_depthwise_BN[0][0]']
#  LU)
#
#  block_9_project (Conv2D)    (None, 32, 32, 64)           24576     ['block_9_depthwise_relu[0][0]
#                                                                     ']
#
#  block_9_project_BN (BatchN  (None, 32, 32, 64)           256       ['block_9_project[0][0]']
#  ormalization)
#
#  block_9_add (Add)           (None, 32, 32, 64)           0         ['block_8_add[0][0]',
#                                                                      'block_9_project_BN[0][0]']
#
#  block_10_expand (Conv2D)    (None, 32, 32, 384)          24576     ['block_9_add[0][0]']
#
#  block_10_expand_BN (BatchN  (None, 32, 32, 384)          1536      ['block_10_expand[0][0]']
#  ormalization)
#
#  block_10_expand_relu (ReLU  (None, 32, 32, 384)          0         ['block_10_expand_BN[0][0]']
#  )
#
#  block_10_depthwise (Depthw  (None, 32, 32, 384)          3456      ['block_10_expand_relu[0][0]']
#  iseConv2D)
#
#  block_10_depthwise_BN (Bat  (None, 32, 32, 384)          1536      ['block_10_depthwise[0][0]']
#  chNormalization)
#
#  block_10_depthwise_relu (R  (None, 32, 32, 384)          0         ['block_10_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_10_project (Conv2D)   (None, 32, 32, 96)           36864     ['block_10_depthwise_relu[0][0
#                                                                     ]']
#
#  block_10_project_BN (Batch  (None, 32, 32, 96)           384       ['block_10_project[0][0]']
#  Normalization)
#
#  block_11_expand (Conv2D)    (None, 32, 32, 576)          55296     ['block_10_project_BN[0][0]']
#
#  block_11_expand_BN (BatchN  (None, 32, 32, 576)          2304      ['block_11_expand[0][0]']
#  ormalization)
#
#  block_11_expand_relu (ReLU  (None, 32, 32, 576)          0         ['block_11_expand_BN[0][0]']
#  )
#
#  block_11_depthwise (Depthw  (None, 32, 32, 576)          5184      ['block_11_expand_relu[0][0]']
#  iseConv2D)
#
#  block_11_depthwise_BN (Bat  (None, 32, 32, 576)          2304      ['block_11_depthwise[0][0]']
#  chNormalization)
#
#  block_11_depthwise_relu (R  (None, 32, 32, 576)          0         ['block_11_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_11_project (Conv2D)   (None, 32, 32, 96)           55296     ['block_11_depthwise_relu[0][0
#                                                                     ]']
#
#  block_11_project_BN (Batch  (None, 32, 32, 96)           384       ['block_11_project[0][0]']
#  Normalization)
#
#  block_11_add (Add)          (None, 32, 32, 96)           0         ['block_10_project_BN[0][0]',
#                                                                      'block_11_project_BN[0][0]']
#
#  block_12_expand (Conv2D)    (None, 32, 32, 576)          55296     ['block_11_add[0][0]']
#
#  block_12_expand_BN (BatchN  (None, 32, 32, 576)          2304      ['block_12_expand[0][0]']
#  ormalization)
#
#  block_12_expand_relu (ReLU  (None, 32, 32, 576)          0         ['block_12_expand_BN[0][0]']
#  )
#
#  block_12_depthwise (Depthw  (None, 32, 32, 576)          5184      ['block_12_expand_relu[0][0]']
#  iseConv2D)
#
#  block_12_depthwise_BN (Bat  (None, 32, 32, 576)          2304      ['block_12_depthwise[0][0]']
#  chNormalization)
#
#  block_12_depthwise_relu (R  (None, 32, 32, 576)          0         ['block_12_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_12_project (Conv2D)   (None, 32, 32, 96)           55296     ['block_12_depthwise_relu[0][0
#                                                                     ]']
#
#  block_12_project_BN (Batch  (None, 32, 32, 96)           384       ['block_12_project[0][0]']
#  Normalization)
#
#  block_12_add (Add)          (None, 32, 32, 96)           0         ['block_11_add[0][0]',
#                                                                      'block_12_project_BN[0][0]']
#
#  block_13_expand (Conv2D)    (None, 32, 32, 576)          55296     ['block_12_add[0][0]']
#
#  block_13_expand_BN (BatchN  (None, 32, 32, 576)          2304      ['block_13_expand[0][0]']
#  ormalization)
#
#  block_13_expand_relu (ReLU  (None, 32, 32, 576)          0         ['block_13_expand_BN[0][0]']
#  )
#
#  block_13_pad (ZeroPadding2  (None, 33, 33, 576)          0         ['block_13_expand_relu[0][0]']
#  D)
#
#  block_13_depthwise (Depthw  (None, 16, 16, 576)          5184      ['block_13_pad[0][0]']
#  iseConv2D)
#
#  block_13_depthwise_BN (Bat  (None, 16, 16, 576)          2304      ['block_13_depthwise[0][0]']
#  chNormalization)
#
#  block_13_depthwise_relu (R  (None, 16, 16, 576)          0         ['block_13_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_13_project (Conv2D)   (None, 16, 16, 160)          92160     ['block_13_depthwise_relu[0][0
#                                                                     ]']
#
#  block_13_project_BN (Batch  (None, 16, 16, 160)          640       ['block_13_project[0][0]']
#  Normalization)
#
#  block_14_expand (Conv2D)    (None, 16, 16, 960)          153600    ['block_13_project_BN[0][0]']
#
#  block_14_expand_BN (BatchN  (None, 16, 16, 960)          3840      ['block_14_expand[0][0]']
#  ormalization)
#
#  block_14_expand_relu (ReLU  (None, 16, 16, 960)          0         ['block_14_expand_BN[0][0]']
#  )
#
#  block_14_depthwise (Depthw  (None, 16, 16, 960)          8640      ['block_14_expand_relu[0][0]']
#  iseConv2D)
#
#  block_14_depthwise_BN (Bat  (None, 16, 16, 960)          3840      ['block_14_depthwise[0][0]']
#  chNormalization)
#
#  block_14_depthwise_relu (R  (None, 16, 16, 960)          0         ['block_14_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_14_project (Conv2D)   (None, 16, 16, 160)          153600    ['block_14_depthwise_relu[0][0
#                                                                     ]']
#
#  block_14_project_BN (Batch  (None, 16, 16, 160)          640       ['block_14_project[0][0]']
#  Normalization)
#
#  block_14_add (Add)          (None, 16, 16, 160)          0         ['block_13_project_BN[0][0]',
#                                                                      'block_14_project_BN[0][0]']
#
#  block_15_expand (Conv2D)    (None, 16, 16, 960)          153600    ['block_14_add[0][0]']
#
#  block_15_expand_BN (BatchN  (None, 16, 16, 960)          3840      ['block_15_expand[0][0]']
#  ormalization)
#
#  block_15_expand_relu (ReLU  (None, 16, 16, 960)          0         ['block_15_expand_BN[0][0]']
#  )
#
#  block_15_depthwise (Depthw  (None, 16, 16, 960)          8640      ['block_15_expand_relu[0][0]']
#  iseConv2D)
#
#  block_15_depthwise_BN (Bat  (None, 16, 16, 960)          3840      ['block_15_depthwise[0][0]']
#  chNormalization)
#
#  block_15_depthwise_relu (R  (None, 16, 16, 960)          0         ['block_15_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_15_project (Conv2D)   (None, 16, 16, 160)          153600    ['block_15_depthwise_relu[0][0
#                                                                     ]']
#
#  block_15_project_BN (Batch  (None, 16, 16, 160)          640       ['block_15_project[0][0]']
#  Normalization)
#
#  block_15_add (Add)          (None, 16, 16, 160)          0         ['block_14_add[0][0]',
#                                                                      'block_15_project_BN[0][0]']
#
#  block_16_expand (Conv2D)    (None, 16, 16, 960)          153600    ['block_15_add[0][0]']
#
#  block_16_expand_BN (BatchN  (None, 16, 16, 960)          3840      ['block_16_expand[0][0]']
#  ormalization)
#
#  block_16_expand_relu (ReLU  (None, 16, 16, 960)          0         ['block_16_expand_BN[0][0]']
#  )
#
#  block_16_depthwise (Depthw  (None, 16, 16, 960)          8640      ['block_16_expand_relu[0][0]']
#  iseConv2D)
#
#  block_16_depthwise_BN (Bat  (None, 16, 16, 960)          3840      ['block_16_depthwise[0][0]']
#  chNormalization)
#
#  block_16_depthwise_relu (R  (None, 16, 16, 960)          0         ['block_16_depthwise_BN[0][0]'
#  eLU)                                                               ]
#
#  block_16_project (Conv2D)   (None, 16, 16, 320)          307200    ['block_16_depthwise_relu[0][0
#                                                                     ]']
#
#  block_16_project_BN (Batch  (None, 16, 16, 320)          1280      ['block_16_project[0][0]']
#  Normalization)
#
#  Conv_1 (Conv2D)             (None, 16, 16, 1280)         409600    ['block_16_project_BN[0][0]']
#
#  Conv_1_bn (BatchNormalizat  (None, 16, 16, 1280)         5120      ['Conv_1[0][0]']
#  ion)
#
#  out_relu (ReLU)             (None, 16, 16, 1280)         0         ['Conv_1_bn[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)          2949376   ['out_relu[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 128)          295040    ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 64)           73792     ['conv2d_4[0][0]']
#
#  global_average_pooling2d_1  (None, 64)                   0         ['conv2d_5[0][0]']
#   (GlobalAveragePooling2D)
#
#  boxes_output (Dense)        (None, 1000)                 65000     ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  reshape_1 (Reshape)         (None, 250, 4)               0         ['boxes_output[0][0]']
#
# ==================================================================================================
# Total params: 5641192 (21.52 MB)
# Trainable params: 3383208 (12.91 MB)
# Non-trainable params: 2257984 (8.61 MB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, LearningRateScheduler
import datetime
import os

# Define the Smooth L1 Loss Function
def smooth_l1_loss(sigma=3.0):
    sigma_squared = sigma ** 2
    
    def smooth_l1_loss_fixed(y_true, y_pred):
        regression_diff = y_true - y_pred
        regression_diff = tf.abs(regression_diff)
        regression_loss = tf.where(
            tf.less(regression_diff, 1.0 / sigma_squared),
            0.5 * sigma_squared * tf.pow(regression_diff, 2),
            regression_diff - 0.5 / sigma_squared
        )
        regression_loss = tf.reduce_sum(regression_loss, axis=-1)
        return tf.reduce_mean(regression_loss)
    
    return smooth_l1_loss_fixed
# Compile the Model with the Custom Loss
model.compile(optimizer='adam',
              loss=smooth_l1_loss(),  # Only use smooth L1 loss for bounding box predictions
              metrics=['mean_squared_error'])  # Added a metric for bounding box prediction quality

# Set up TensorBoard logging
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# Set up checkpoints to save the model
checkpoint_dir = "checkpoints/"
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)
checkpoint_path = checkpoint_dir + "cp-{epoch:04d}.ckpt"
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=1,
    save_weights_only=True,
    save_best_only=False  # Set to True to save only the best model based on validation loss
)

# Define a Learning Rate Schedule
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    elif epoch%10 == 0:
        return lr * tf.math.exp(-0.1)
    else:
        return lr

learning_rate_callback = LearningRateScheduler(scheduler)

# %%
# Fit the Model on the Prepared Dataset
# The dataset should output a tuple of (images, boxes)
history = model.fit(
    dataset,
    epochs=500,
    callbacks=[tensorboard_callback, checkpoint_callback, learning_rate_callback])  # Add the callbacks here
# Out:
# Epoch 1/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0066 - mean_squared_error: 3.8920e-04
# Epoch 1: saving model to checkpoints/cp-0001.ckpt
# 10/10 [==============================] - 3s 189ms/step - loss: 0.0066 - mean_squared_error: 3.8920e-04 - lr: 0.0010
# Epoch 2/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0262 - mean_squared_error: 0.0015
# Epoch 2: saving model to checkpoints/cp-0002.ckpt
# 10/10 [==============================] - 2s 201ms/step - loss: 0.0264 - mean_squared_error: 0.0015 - lr: 0.0010
# Epoch 3/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0126 - mean_squared_error: 7.2372e-04
# Epoch 3: saving model to checkpoints/cp-0003.ckpt
# 10/10 [==============================] - 2s 199ms/step - loss: 0.0126 - mean_squared_error: 7.2372e-04 - lr: 0.0010
# Epoch 4/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0100 - mean_squared_error: 5.7870e-04
# Epoch 4: saving model to checkpoints/cp-0004.ckpt
# 10/10 [==============================] - 2s 187ms/step - loss: 0.0098 - mean_squared_error: 5.6245e-04 - lr: 0.0010
# Epoch 5/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0061 - mean_squared_error: 3.5848e-04
# Epoch 5: saving model to checkpoints/cp-0005.ckpt
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0060 - mean_squared_error: 3.5314e-04 - lr: 0.0010
# Epoch 6/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0067 - mean_squared_error: 3.9248e-04
# Epoch 6: saving model to checkpoints/cp-0006.ckpt
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0066 - mean_squared_error: 3.8259e-04 - lr: 0.0010
# Epoch 7/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0054 - mean_squared_error: 3.1593e-04
# Epoch 7: saving model to checkpoints/cp-0007.ckpt
# 10/10 [==============================] - 2s 200ms/step - loss: 0.0054 - mean_squared_error: 3.1593e-04 - lr: 0.0010
# Epoch 8/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.
# Epoch 20/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0030 - mean_squared_error: 1.8271e-04
# Epoch 20: saving model to checkpoints/cp-0020.ckpt
# 10/10 [==============================] - 2s 245ms/step - loss: 0.0030 - mean_squared_error: 1.8271e-04 - lr: 9.0484e-04
# Epoch 21/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0027 - mean_squared_error: 1.6219e-04
# Epoch 21: saving model to checkpoints/cp-0021.ckpt
# 10/10 [==============================] - 2s 258ms/step - loss: 0.0027 - mean_squared_error: 1.6219e-04 - lr: 8.1873e-04
# Epoch 22/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0026 - mean_squared_error: 1.5904e-04
# Epoch 22: saving model to checkpoints/cp-0022.ckpt
# 10/10 [==============================] - 3s 267ms/step - loss: 0.0026 - mean_squared_error: 1.5904e-04 - lr: 8.1873e-04
# Epoch 23/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0014 - mean_squared_error: 9.0425e-05
# Epoch 23: saving model to checkpoints/cp-0023.ckpt
# 10/10 [==============================] - 3s 283ms/step - loss: 0.0014 - mean_squared_error: 9.0425e-05 - lr: 8.1873e-04
# Epoch 24/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0014 - mean_squared_error: 8.7956e-05
# Epoch 24: saving model to checkpoints/cp-0024.ckpt
# 10/10 [==============================] - 3s 296ms/step - loss: 0.0014 - mean_squared_error: 8.7956e-05 - lr: 8.1873e-04
# Epoch 25/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0012 - mean_squared_error: 7.2621e-05
# Epoch 25: saving model to checkpoints/cp-0025.ckpt
# 10/10 [==============================] - 3s 271ms/step - loss: 0.0012 - mean_squared_error: 7.2621e-05 - lr: 8.1873e-04
# Epoch 26/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0012 - mean_squared_error: 7.0048e-05
# Epoch 26: saving model to checkpoints/cp-0026.ckpt
# 10/10 [==============================] - 2s 202ms/step - loss: 0.0012 - mean_squared_error: 7.0048e-05 - lr: 8.1873e-04
# Epoch 27/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0013 - mean_squared_error: 7.3767e-05
# Epoch 27: saving model to checkpoints/cp-0027.ckpt
# 10/10 [==============================] - 2s 202ms/step - loss: 0.0013 - mean_squared_error: 7.3767e-05 - lr: 8.1873e-04
# Epoch 28/500
# 10/10 [==============================] - ETA: 0s - loss: 9.8443e-04 - mean_squared_error: 5.5627e-05
# Epoch 28: saving model to checkpoints/cp-0028.ckpt
# 10/10 [==============================] - 2s 186ms/step - loss: 9.8443e-04 - mean_squared_error: 5.5627e-05 - lr: 8.1873e-04
# Epoch 29/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0011 - mean_squared_error: 6.0943e-05
# Epoch 29: saving model to checkpoints/cp-0029.ckpt
# 10/10 [==============================] - 2s 188ms/step - loss: 0.0010 - mean_squared_error: 5.8657e-05 - lr: 8.1873e-04
# Epoch 30/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0011 - mean_squared_error: 6.0663e-05
# Epoch 30: saving model to checkpoints/cp-0030.ckpt
# 10/10 [==============================] - 2s 184ms/step - loss: 0.0011 - mean_squared_error: 6.0663e-05 - lr: 8.1873e-04
# Epoch 31/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0071 - mean_squared_error: 3.9553e-04
# Epoch 42: saving model to checkpoints/cp-0042.ckpt
# 10/10 [==============================] - 2s 172ms/step - loss: 0.0070 - mean_squared_error: 3.8821e-04 - lr: 6.7032e-04
# Epoch 43/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0040 - mean_squared_error: 2.2200e-04
# Epoch 43: saving model to checkpoints/cp-0043.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 0.0047 - mean_squared_error: 2.5927e-04 - lr: 6.7032e-04
# Epoch 44/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0054 - mean_squared_error: 3.0074e-04
# Epoch 44: saving model to checkpoints/cp-0044.ckpt
# 10/10 [==============================] - 2s 176ms/step - loss: 0.0052 - mean_squared_error: 2.8818e-04 - lr: 6.7032e-04
# Epoch 45/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0042 - mean_squared_error: 2.3262e-04
# Epoch 45: saving model to checkpoints/cp-0045.ckpt
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0042 - mean_squared_error: 2.3262e-04 - lr: 6.7032e-04
# Epoch 46/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0035 - mean_squared_error: 1.9502e-04
# Epoch 46: saving model to checkpoints/cp-0046.ckpt
# 10/10 [==============================] - 2s 220ms/step - loss: 0.0035 - mean_squared_error: 1.9502e-04 - lr: 6.7032e-04
# Epoch 47/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0022 - mean_squared_error: 1.2438e-04
# Epoch 47: saving model to checkpoints/cp-0047.ckpt
# 10/10 [==============================] - 2s 224ms/step - loss: 0.0022 - mean_squared_error: 1.2438e-04 - lr: 6.7032e-04
# Epoch 48/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0015 - mean_squared_error: 8.5785e-05
# Epoch 48: saving model to checkpoints/cp-0048.ckpt
# 10/10 [==============================] - 2s 198ms/step - loss: 0.0015 - mean_squared_error: 8.5785e-05 - lr: 6.7032e-04
# Epoch 49/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0013 - mean_squared_error: 7.3821e-05
# Epoch 49: saving model to checkpoints/cp-0049.ckpt
# 10/10 [==============================] - 2s 182ms/step - loss: 0.0013 - mean_squared_error: 7.3821e-05 - lr: 6.7032e-04
# Epoch 50/500
#  9/10 [==========================>...] - ETA: 0s - loss: 9.8145e-04 - mean_squared_error: 5.4525e-05
# Epoch 50: saving model to checkpoints/cp-0050.ckpt
# 10/10 [==============================] - 2s 179ms/step - loss: 0.0011 - mean_squared_error: 6.0027e-05 - lr: 6.7032e-04
# Epoch 51/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0016 - mean_squared_error: 8.9527e-05
# Epoch 51: saving model to checkpoints/cp-0051.ckpt
# 10/10 [==============================] - 2s 189ms/step - loss: 0.0016 - mean_squared_error: 8.9527e-05 - lr: 6.0653e-04
# Epoch 52/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0030 - mean_squared_error: 1.6747e-04
# Epoch 52: saving model to checkpoints/cp-0052.ckpt
# 10/10 [==============================] - 2s 184ms/step - loss: 0.0029 - mean_squared_error: 1.5977e-04 - lr: 6.0653e-04
# Epoch 53/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0019 - mean_squared_error: 1.0480e-04
# Epoch 53: saving model to checkpoints/cp-0053.ckpt
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0018 - mean_squared_error: 1.0170e-04 - lr: 6.0653e-04
# Epoch 54/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0015 - mean_squared_error: 8.1748e-05
# Epoch 54: saving model to checkpoints/cp-0054.ckpt
# 10/10 [==============================] - 2s 205ms/step - loss: 0.0015 - mean_squared_error: 8.1748e-05 - lr: 6.0653e-04
# Epoch 55/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0028 - mean_squared_error: 1.5488e-04
# Epoch 55: saving model to checkpoints/cp-0055.ckpt
# 10/10 [==============================] - 2s 196ms/step - loss: 0.0028 - mean_squared_error: 1.5488e-04 - lr: 6.0653e-04
# Epoch 56/500
# 10/10 [==============================] - ETA: 0s - loss: 0.0017 - mean_squared_error: 9.6693e-05
# Epoch 56: saving model to checkpoints/cp-0056.ckpt
# 10/10 [==============================] - 2s 196ms/step - loss: 0.0017 - mean_squared_error: 9.6693e-05 - lr: 6.0653e-04
# Epoch 57/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0017 - mean_squared_error: 9.2975e-05
# Epoch 57: saving model to checkpoints/cp-0057.ckpt
# 10/10 [==============================] - 2s 184ms/step - loss: 0.0016 - mean_squared_error: 8.8865e-05 - lr: 6.0653e-04
# Epoch 58/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0028 - mean_squared_error: 1.5356e-04
# Epoch 58: saving model to checkpoints/cp-0058.ckpt
# 10/10 [==============================] - 2s 179ms/step - loss: 0.0027 - mean_squared_error: 1.4887e-04 - lr: 6.0653e-04
# Epoch 59/500
#  9/10 [==========================>...] - ETA: 0s - loss: 0.0014 - mean_squared_error: 8.0478e-05
# Epoch 59: saving model to checkpoints/cp-0059.ckpt
# 10/10 [==============================] - 2s 173ms/step - loss: 0.0014 - mean_squared_error: 7.7115e-05 - lr: 6.0653e-04
# Epoch 60/500
# 10/10 [==============================] - ETA: 0s - loss: 6.7469e-04 - mean_squared_error: 3.7483e-05
# Epoch 60: saving model to checkpoints/cp-0060.ckpt
# 10/10 [==============================] - 2s 181ms/step - loss: 6.7469e-04 - mean_squared_error: 3.7483e-05 - lr: 6.0653e-04
# Epoch 61/500
# 10/10 [==============================] - ETA: 0s - loss: 6.6088e-04 - mean_squared_error: 3.6715e-05
# Epoch 61: saving model to checkpoints/cp-0061.ckpt
# 10/10 [==============================] - 2s 189ms/step - loss: 6.6088e-04 - mean_squared_error: 3.6715e-05 - lr: 5.4881e-04
# Epoch 62/500
#  9/10 [==========================>...] - ETA: 0s - loss: 4.8285e-04 - mean_squared_error: 2.6825e-05
# Epoch 62: saving model to checkpoints/cp-0062.ckpt
# 10/10 [==============================] - 2s 190ms/step - loss: 4.8520e-04 - mean_squared_error: 2.6956e-05 - lr: 5.4881e-04
# Epoch 63/500
# 10/10 [==============================] - ETA: 0s - loss: 3.5056e-04 - mean_squared_error: 1.9476e-05
# Epoch 63: saving model to checkpoints/cp-0063.ckpt
# Epoch 142: saving model to checkpoints/cp-0142.ckpt
# 10/10 [==============================] - 2s 180ms/step - loss: 2.4608e-05 - mean_squared_error: 1.3671e-06 - lr: 2.4660e-04
# Epoch 143/500
# 10/10 [==============================] - ETA: 0s - loss: 2.4373e-05 - mean_squared_error: 1.3540e-06
# Epoch 143: saving model to checkpoints/cp-0143.ckpt
# 10/10 [==============================] - 2s 179ms/step - loss: 2.4373e-05 - mean_squared_error: 1.3540e-06 - lr: 2.4660e-04
# Epoch 144/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.4798e-05 - mean_squared_error: 1.3777e-06
# Epoch 144: saving model to checkpoints/cp-0144.ckpt
# 10/10 [==============================] - 2s 169ms/step - loss: 2.4111e-05 - mean_squared_error: 1.3395e-06 - lr: 2.4660e-04
# Epoch 145/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.4170e-05 - mean_squared_error: 1.3428e-06
# Epoch 145: saving model to checkpoints/cp-0145.ckpt
# 10/10 [==============================] - 2s 174ms/step - loss: 2.3787e-05 - mean_squared_error: 1.3215e-06 - lr: 2.4660e-04
# Epoch 146/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.2635e-05 - mean_squared_error: 1.2575e-06
# Epoch 146: saving model to checkpoints/cp-0146.ckpt
# 10/10 [==============================] - 2s 167ms/step - loss: 2.3591e-05 - mean_squared_error: 1.3106e-06 - lr: 2.4660e-04
# Epoch 147/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.3689e-05 - mean_squared_error: 1.3160e-06
# Epoch 147: saving model to checkpoints/cp-0147.ckpt
# 10/10 [==============================] - 2s 182ms/step - loss: 2.3306e-05 - mean_squared_error: 1.2948e-06 - lr: 2.4660e-04
# Epoch 148/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.3080e-05 - mean_squared_error: 1.2822e-06
# Epoch 148: saving model to checkpoints/cp-0148.ckpt
# 10/10 [==============================] - 2s 193ms/step - loss: 2.3037e-05 - mean_squared_error: 1.2799e-06 - lr: 2.4660e-04
# Epoch 149/500
# 10/10 [==============================] - ETA: 0s - loss: 2.2755e-05 - mean_squared_error: 1.2642e-06
# Epoch 149: saving model to checkpoints/cp-0149.ckpt
# 10/10 [==============================] - 2s 187ms/step - loss: 2.2755e-05 - mean_squared_error: 1.2642e-06 - lr: 2.4660e-04
# Epoch 150/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.3167e-05 - mean_squared_error: 1.2870e-06
# Epoch 150: saving model to checkpoints/cp-0150.ckpt
# 10/10 [==============================] - 2s 183ms/step - loss: 2.2494e-05 - mean_squared_error: 1.2497e-06 - lr: 2.4660e-04
# Epoch 151/500
# 10/10 [==============================] - ETA: 0s - loss: 2.2249e-05 - mean_squared_error: 1.2361e-06
# Epoch 151: saving model to checkpoints/cp-0151.ckpt
# 10/10 [==============================] - 2s 194ms/step - loss: 2.2249e-05 - mean_squared_error: 1.2361e-06 - lr: 2.2313e-04
# Epoch 152/500
# 10/10 [==============================] - ETA: 0s - loss: 2.2036e-05 - mean_squared_error: 1.2242e-06
# Epoch 152: saving model to checkpoints/cp-0152.ckpt
# 10/10 [==============================] - 2s 188ms/step - loss: 2.2036e-05 - mean_squared_error: 1.2242e-06 - lr: 2.2313e-04
# Epoch 153/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.2778e-05 - mean_squared_error: 1.2654e-06
# Epoch 153: saving model to checkpoints/cp-0153.ckpt
# 10/10 [==============================] - 2s 169ms/step - loss: 2.1823e-05 - mean_squared_error: 1.2124e-06 - lr: 2.2313e-04
# Epoch 154/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.1731e-05 - mean_squared_error: 1.2073e-06
# Epoch 154: saving model to checkpoints/cp-0154.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 2.1581e-05 - mean_squared_error: 1.1989e-06 - lr: 2.2313e-04
# Epoch 155/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.0861e-05 - mean_squared_error: 1.1589e-06
# Epoch 155: saving model to checkpoints/cp-0155.ckpt
# 10/10 [==============================] - 2s 180ms/step - loss: 2.1387e-05 - mean_squared_error: 1.1882e-06 - lr: 2.2313e-04
# Epoch 156/500
# 10/10 [==============================] - ETA: 0s - loss: 2.1143e-05 - mean_squared_error: 1.1746e-06
# Epoch 156: saving model to checkpoints/cp-0156.ckpt
# 10/10 [==============================] - 2s 188ms/step - loss: 2.1143e-05 - mean_squared_error: 1.1746e-06 - lr: 2.2313e-04
# Epoch 157/500
# 10/10 [==============================] - ETA: 0s - loss: 2.0980e-05 - mean_squared_error: 1.1656e-06
# Epoch 157: saving model to checkpoints/cp-0157.ckpt
# 10/10 [==============================] - 2s 191ms/step - loss: 2.0980e-05 - mean_squared_error: 1.1656e-06 - lr: 2.2313e-04
# Epoch 158/500
#  9/10 [==========================>...] - ETA: 0s - loss: 1.9838e-05 - mean_squared_error: 1.1021e-06
# Epoch 158: saving model to checkpoints/cp-0158.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 2.0729e-05 - mean_squared_error: 1.1516e-06 - lr: 2.2313e-04
# Epoch 159/500
#  9/10 [==========================>...] - ETA: 0s - loss: 1.9675e-05 - mean_squared_error: 1.0931e-06
# Epoch 159: saving model to checkpoints/cp-0159.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 2.0528e-05 - mean_squared_error: 1.1404e-06 - lr: 2.2313e-04
# Epoch 160/500
#  9/10 [==========================>...] - ETA: 0s - loss: 2.0546e-05 - mean_squared_error: 1.1415e-06
# Epoch 160: saving model to checkpoints/cp-0160.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 2.0344e-05 - mean_squared_error: 1.1302e-06 - lr: 2.2313e-04
# Epoch 161/500
#  9/10 [==========================>...] - ETA: 0s - loss: 1.9672e-05 - mean_squared_error: 1.0929e-06
# Epoch 161: saving model to checkpoints/cp-0161.ckpt
# 10/10 [==============================] - 2s 174ms/step - loss: 2.0184e-05 - mean_squared_error: 1.1213e-06 - lr: 2.0190e-04
# Epoch 162/500
# 10/10 [==============================] - ETA: 0s - loss: 1.9952e-05 - mean_squared_error: 1.1085e-06
# Epoch 162: saving model to checkpoints/cp-0162.ckpt
# 10/10 [==============================] - 2s 183ms/step - loss: 1.9952e-05 - mean_squared_error: 1.1085e-06 - lr: 2.0190e-04
# Epoch 163/500
# 10/10 [==============================] - ETA: 0s - loss: 1.9737e-05 - mean_squared_error: 1.0965e-06
# Epoch 163: saving model to checkpoints/cp-0163.ckpt
# 10/10 [==============================] - 2s 199ms/step - loss: 1.9737e-05 - mean_squared_error: 1.0965e-06 - lr: 2.0190e-04
# Epoch 164/500
#  9/10 [==========================>...] - ETA: 0s - loss: 1.9575e-05 - mean_squared_error: 1.0875e-06
# Epoch 164: saving model to checkpoints/cp-0164.ckpt
# 10/10 [==============================] - 2s 198ms/step - loss: 1.9569e-05 - mean_squared_error: 1.0872e-06 - lr: 2.0190e-04
# Epoch 165/500
# 10/10 [==============================] - ETA: 0s - loss: 1.9379e-05 - mean_squared_error: 1.0766e-06
# Epoch 165: saving model to checkpoints/cp-0165.ckpt
# 10/10 [==============================] - 2s 194ms/step - loss: 1.9379e-05 - mean_squared_error: 1.0766e-06 - lr: 2.0190e-04
# Epoch 166/500
# 10/10 [==============================] - ETA: 0s - loss: 1.9206e-05 - mean_squared_error: 1.0670e-06
# Epoch 166: saving model to checkpoints/cp-0166.ckpt
# 10/10 [==============================] - 2s 190ms/step - loss: 1.9206e-05 - mean_squared_error: 1.0670e-06 - lr: 2.0190e-04
# Epoch 167/500
# 10/10 [==============================] - ETA: 0s - loss: 1.9061e-05 - mean_squared_error: 1.0589e-06
# Epoch 167: saving model to checkpoints/cp-0167.ckpt
# 10/10 [==============================] - 2s 177ms/step - loss: 1.9061e-05 - mean_squared_error: 1.0589e-06 - lr: 2.0190e-04
# Epoch 168/500
#  9/10 [==========================>...] - ETA: 0s - loss: 1.9043e-05 - mean_squared_error: 1.0579e-06
# ...
# 10/10 [==============================] - ETA: 0s - loss: 7.4150e-06 - mean_squared_error: 4.1195e-07
# Epoch 446: saving model to checkpoints/cp-0446.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 7.4150e-06 - mean_squared_error: 4.1195e-07 - lr: 1.2277e-05
# Epoch 447/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.3472e-06 - mean_squared_error: 4.0818e-07
# Epoch 447: saving model to checkpoints/cp-0447.ckpt
# 10/10 [==============================] - 2s 180ms/step - loss: 7.4068e-06 - mean_squared_error: 4.1149e-07 - lr: 1.2277e-05
# Epoch 448/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.4650e-06 - mean_squared_error: 4.1472e-07
# Epoch 448: saving model to checkpoints/cp-0448.ckpt
# 10/10 [==============================] - 2s 188ms/step - loss: 7.3993e-06 - mean_squared_error: 4.1107e-07 - lr: 1.2277e-05
# Epoch 449/500
# 10/10 [==============================] - ETA: 0s - loss: 7.3904e-06 - mean_squared_error: 4.1058e-07
# Epoch 479/500
# 10/10 [==============================] - ETA: 0s - loss: 7.1725e-06 - mean_squared_error: 3.9847e-07
# Epoch 479: saving model to checkpoints/cp-0479.ckpt
# 10/10 [==============================] - 3s 262ms/step - loss: 7.1725e-06 - mean_squared_error: 3.9847e-07 - lr: 9.0953e-06
# Epoch 480/500
# 10/10 [==============================] - ETA: 0s - loss: 7.1686e-06 - mean_squared_error: 3.9825e-07
# Epoch 480: saving model to checkpoints/cp-0480.ckpt
# 10/10 [==============================] - 3s 265ms/step - loss: 7.1686e-06 - mean_squared_error: 3.9825e-07 - lr: 9.0953e-06
# Epoch 481/500
# 10/10 [==============================] - ETA: 0s - loss: 7.1599e-06 - mean_squared_error: 3.9777e-07
# Epoch 481: saving model to checkpoints/cp-0481.ckpt
# 10/10 [==============================] - 3s 270ms/step - loss: 7.1599e-06 - mean_squared_error: 3.9777e-07 - lr: 8.2298e-06
# Epoch 482/500
# 10/10 [==============================] - ETA: 0s - loss: 7.1536e-06 - mean_squared_error: 3.9742e-07
# Epoch 482: saving model to checkpoints/cp-0482.ckpt
# 10/10 [==============================] - 2s 239ms/step - loss: 7.1536e-06 - mean_squared_error: 3.9742e-07 - lr: 8.2298e-06
# Epoch 483/500
# 10/10 [==============================] - ETA: 0s - loss: 7.1489e-06 - mean_squared_error: 3.9716e-07
# Epoch 483: saving model to checkpoints/cp-0483.ckpt
# 10/10 [==============================] - 2s 223ms/step - loss: 7.1489e-06 - mean_squared_error: 3.9716e-07 - lr: 8.2298e-06
# Epoch 484/500
#  9/10 [==========================>...] - ETA: 0s - loss: 6.7973e-06 - mean_squared_error: 3.7763e-07
# Epoch 484: saving model to checkpoints/cp-0484.ckpt
# 10/10 [==============================] - 2s 195ms/step - loss: 7.1413e-06 - mean_squared_error: 3.9674e-07 - lr: 8.2298e-06
# Epoch 485/500
# 10/10 [==============================] - ETA: 0s - loss: 7.1347e-06 - mean_squared_error: 3.9637e-07
# Epoch 485: saving model to checkpoints/cp-0485.ckpt
# 10/10 [==============================] - 2s 184ms/step - loss: 7.1347e-06 - mean_squared_error: 3.9637e-07 - lr: 8.2298e-06
# Epoch 486/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.3996e-06 - mean_squared_error: 4.1109e-07
# Epoch 486: saving model to checkpoints/cp-0486.ckpt
# 10/10 [==============================] - 2s 181ms/step - loss: 7.1296e-06 - mean_squared_error: 3.9609e-07 - lr: 8.2298e-06
# Epoch 487/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.1673e-06 - mean_squared_error: 3.9818e-07
# Epoch 487: saving model to checkpoints/cp-0487.ckpt
# 10/10 [==============================] - 2s 181ms/step - loss: 7.1229e-06 - mean_squared_error: 3.9572e-07 - lr: 8.2298e-06
# Epoch 488/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.0951e-06 - mean_squared_error: 3.9417e-07
# Epoch 488: saving model to checkpoints/cp-0488.ckpt
# 10/10 [==============================] - 2s 173ms/step - loss: 7.1160e-06 - mean_squared_error: 3.9533e-07 - lr: 8.2298e-06
# Epoch 489/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.1758e-06 - mean_squared_error: 3.9866e-07
# Epoch 489: saving model to checkpoints/cp-0489.ckpt
# 10/10 [==============================] - 2s 174ms/step - loss: 7.1108e-06 - mean_squared_error: 3.9504e-07 - lr: 8.2298e-06
# Epoch 490/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.0818e-06 - mean_squared_error: 3.9343e-07
# Epoch 490: saving model to checkpoints/cp-0490.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 7.1041e-06 - mean_squared_error: 3.9467e-07 - lr: 8.2298e-06
# Epoch 491/500
# 10/10 [==============================] - ETA: 0s - loss: 7.0980e-06 - mean_squared_error: 3.9433e-07
# Epoch 491: saving model to checkpoints/cp-0491.ckpt
# 10/10 [==============================] - 2s 187ms/step - loss: 7.0980e-06 - mean_squared_error: 3.9433e-07 - lr: 7.4466e-06
# Epoch 492/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.0719e-06 - mean_squared_error: 3.9288e-07
# Epoch 492: saving model to checkpoints/cp-0492.ckpt
# 10/10 [==============================] - 2s 195ms/step - loss: 7.0926e-06 - mean_squared_error: 3.9403e-07 - lr: 7.4466e-06
# Epoch 493/500
# 10/10 [==============================] - ETA: 0s - loss: 7.0861e-06 - mean_squared_error: 3.9367e-07
# Epoch 493: saving model to checkpoints/cp-0493.ckpt
# 10/10 [==============================] - 2s 181ms/step - loss: 7.0861e-06 - mean_squared_error: 3.9367e-07 - lr: 7.4466e-06
# Epoch 494/500
#  9/10 [==========================>...] - ETA: 0s - loss: 6.7443e-06 - mean_squared_error: 3.7468e-07
# Epoch 494: saving model to checkpoints/cp-0494.ckpt
# 10/10 [==============================] - 2s 175ms/step - loss: 7.0806e-06 - mean_squared_error: 3.9337e-07 - lr: 7.4466e-06
# Epoch 495/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.3319e-06 - mean_squared_error: 4.0733e-07
# Epoch 495: saving model to checkpoints/cp-0495.ckpt
# 10/10 [==============================] - 2s 171ms/step - loss: 7.0740e-06 - mean_squared_error: 3.9300e-07 - lr: 7.4466e-06
# Epoch 496/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.1124e-06 - mean_squared_error: 3.9513e-07
# Epoch 496: saving model to checkpoints/cp-0496.ckpt
# 10/10 [==============================] - 2s 170ms/step - loss: 7.0686e-06 - mean_squared_error: 3.9270e-07 - lr: 7.4466e-06
# Epoch 497/500
#  9/10 [==========================>...] - ETA: 0s - loss: 6.9955e-06 - mean_squared_error: 3.8864e-07
# Epoch 497: saving model to checkpoints/cp-0497.ckpt
# 10/10 [==============================] - 2s 175ms/step - loss: 7.0627e-06 - mean_squared_error: 3.9237e-07 - lr: 7.4466e-06
# Epoch 498/500
#  9/10 [==========================>...] - ETA: 0s - loss: 6.7259e-06 - mean_squared_error: 3.7366e-07
# Epoch 498: saving model to checkpoints/cp-0498.ckpt
# 10/10 [==============================] - 2s 172ms/step - loss: 7.0573e-06 - mean_squared_error: 3.9207e-07 - lr: 7.4466e-06
# Epoch 499/500
#  9/10 [==========================>...] - ETA: 0s - loss: 7.0336e-06 - mean_squared_error: 3.9075e-07
# Epoch 499: saving model to checkpoints/cp-0499.ckpt
# 10/10 [==============================] - 2s 178ms/step - loss: 7.0512e-06 - mean_squared_error: 3.9173e-07 - lr: 7.4466e-06
# Epoch 500/500
#  9/10 [==========================>...] - ETA: 0s - loss: 6.9856e-06 - mean_squared_error: 3.8809e-07
# Epoch 500: saving model to checkpoints/cp-0500.ckpt
# 10/10 [==============================] - 2s 178ms/step - loss: 7.0448e-06 - mean_squared_error: 3.9138e-07 - lr: 7.4466e-06

# %%
model.save('TMA_core_predictor.h5')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

def plot_image_with_boxes(image, true_boxes, pred_boxes, figsize=(10, 10)):
    """
    Plots an image with overlaid true and predicted bounding boxes, ensuring visibility even when boxes overlap.
    
    Args:
    image: The image as a NumPy array, normalized between [-1, 1].
    true_boxes: A NumPy array of true bounding boxes of shape (N, 4), where N is the number of boxes,
                and each box is defined as (ymin, xmin, ymax, xmax).
    pred_boxes: A NumPy array of predicted bounding boxes of shape (N, 4), similar to true_boxes.
    figsize: Size of the figure to display.
    """
    # Rescale the image from [-1,1] to [0,1] for displaying
    image = (image + 1) / 2.0

    fig, ax = plt.subplots(1, figsize=figsize)
    ax.imshow(image)  # If the image is not grayscale, remove cmap='gray'

    img_height, img_width = image.shape[:2]
    
    # Plot true bounding boxes
    for box in true_boxes:
        if np.all(box == 0):
            continue  # Skip boxes that are all zeros (used for padding)
        ymin, xmin, ymax, xmax = box
        ymin *= img_height
        ymax *= img_height
        xmin *= img_width
        xmax *= img_width
        # Use a solid line for true boxes
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=2, edgecolor='limegreen', facecolor='none', linestyle='-', label='True')
        ax.add_patch(rect)
    
    # Plot predicted bounding boxes
    for box in pred_boxes:
        if np.all(box == 0):
            continue  # Skip boxes that are all zeros (used for padding)
        ymin, xmin, ymax, xmax = box
        ymin *= img_height
        ymax *= img_height
        xmin *= img_width
        xmax *= img_width
        # Use a dashed line for predicted boxes
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                 linewidth=2, edgecolor='red', facecolor='none', linestyle='--', alpha=1, label='Pred')
        ax.add_patch(rect)

    # Create a legend
    handles, labels = ax.get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    # This ensures that only one label for each line style is added to the legend
    unique_labels = list(set(labels))
    unique_handles = [by_label[label] for label in unique_labels]
    ax.legend(unique_handles, unique_labels)
    
    plt.show()


image = 5 # Select an index of an image to display

pred_boxes = model.predict(images[image:image+1])  # Predict the bounding boxes for the 11th image
# Rescale predictions if necessary here

true_boxes = pad_labels(boxes)


plot_image_with_boxes(images[image], true_boxes[image], pred_boxes[0])
# Out:
# 1/1 [==============================] - 0s 398ms/step
