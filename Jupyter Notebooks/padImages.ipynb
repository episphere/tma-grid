# %%
import os
import json
from PIL import Image

import os
import json
from PIL import Image
def pad_and_crop_image_and_update_labels(image_path, label_path, output_image_path, output_label_path, desired_height=1024, desired_width=1024):
    # Open the image
    image = Image.open(image_path)
    original_width, original_height = image.size

    # Read the label data
    with open(label_path, 'r') as label_file:
        labels = json.load(label_file)

    # Check if image needs cropping or padding
    if original_width > desired_width or original_height > desired_height:
        # Crop the image
        new_image = image.crop((0, 0, min(desired_width, original_width), min(desired_height, original_height)))

        # Filter out labels that fall outside the desired dimensions
        labels = [label for label in labels if label['x'] < desired_width and label['y'] < desired_height]
    else:
        # Pad the image
        new_image = Image.new("RGB", (max(desired_width, original_width), max(desired_height, original_height)), (255, 255, 255))
        new_image.paste(image, (0, 0))

    # Save the new image
    new_image.save(output_image_path)

    # Save updated labels
    with open(output_label_path, 'w') as label_file:
        json.dump(labels, label_file, indent=4)

    print(f"Processed {image_path}; saved new image to {output_image_path} and labels to {output_label_path}")

# Directory containing images and labels
image_directory = "./TMA_WSI_PNGs"
label_directory = "TMA_WSI_Labels_old"

# image_directory = "./augmented_images"
# label_directory = "./augmented_labels"


# output_image_directory = "./augmented_images_updated"
# output_label_directory = "./augmented_labels_updated"

output_image_directory = "./TMA_WSI_Padded_PNGs"
output_label_directory = "./TMA_WSI_Labels_updated"

# Make sure the output directories exist
os.makedirs(output_image_directory, exist_ok=True)
os.makedirs(output_label_directory, exist_ok=True)

# Iterate over all files in the directory
for filename in os.listdir(image_directory):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        image_path = os.path.join(image_directory, filename)
        label_path = os.path.join(label_directory, os.path.splitext(filename)[0] + '.json')
        output_image_path = os.path.join(output_image_directory, filename)
        output_label_path = os.path.join(output_label_directory, os.path.splitext(filename)[0] + '.json')

        if os.path.exists(label_path):
            pad_and_crop_image_and_update_labels(image_path, label_path, output_image_path, output_label_path)
        else:
            print(f"No label found for {filename}, skipping.")
# Out:
# Processed ./TMA_WSI_PNGs/ABC_106_1_010_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_106_1_010_1.png and labels to ./TMA_WSI_Labels_updated/ABC_106_1_010_1.json
# Processed ./TMA_WSI_PNGs/ABC_099_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_099_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_099_1_009_1.json
# Processed ./TMA_WSI_PNGs/158868.png; saved new image to ./TMA_WSI_Padded_PNGs/158868.png and labels to ./TMA_WSI_Labels_updated/158868.json
# Processed ./TMA_WSI_PNGs/ABC_103_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_103_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_103_1_009_1.json
# Processed ./TMA_WSI_PNGs/158869.png; saved new image to ./TMA_WSI_Padded_PNGs/158869.png and labels to ./TMA_WSI_Labels_updated/158869.json
# Processed ./TMA_WSI_PNGs/ABC_096_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_096_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_096_1_009_1.json
# Processed ./TMA_WSI_PNGs/ABC_109_1_010_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_109_1_010_1.png and labels to ./TMA_WSI_Labels_updated/ABC_109_1_010_1.json
# Processed ./TMA_WSI_PNGs/ABC_100_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_100_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_100_1_009_1.json
# Processed ./TMA_WSI_PNGs/ABC_105_1_010_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_105_1_010_1.png and labels to ./TMA_WSI_Labels_updated/ABC_105_1_010_1.json
# Processed ./TMA_WSI_PNGs/ABC_102_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_102_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_102_1_009_1.json
# Processed ./TMA_WSI_PNGs/ABC_098_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_098_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_098_1_009_1.json
# Processed ./TMA_WSI_PNGs/ABC_107_1_010_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_107_1_010_1.png and labels to ./TMA_WSI_Labels_updated/ABC_107_1_010_1.json
# Processed ./TMA_WSI_PNGs/158867.png; saved new image to ./TMA_WSI_Padded_PNGs/158867.png and labels to ./TMA_WSI_Labels_updated/158867.json
# Processed ./TMA_WSI_PNGs/158870.png; saved new image to ./TMA_WSI_Padded_PNGs/158870.png and labels to ./TMA_WSI_Labels_updated/158870.json
# Processed ./TMA_WSI_PNGs/ABC_104_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_104_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_104_1_009_1.json
# Processed ./TMA_WSI_PNGs/158871.png; saved new image to ./TMA_WSI_Padded_PNGs/158871.png and labels to ./TMA_WSI_Labels_updated/158871.json
# Processed ./TMA_WSI_PNGs/ABC_101_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_101_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_101_1_009_1.json
# Processed ./TMA_WSI_PNGs/ABC_108_1_010_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_108_1_010_1.png and labels to ./TMA_WSI_Labels_updated/ABC_108_1_010_1.json
# Processed ./TMA_WSI_PNGs/ABC_097_1_009_1.png; saved new image to ./TMA_WSI_Padded_PNGs/ABC_097_1_009_1.png and labels to ./TMA_WSI_Labels_updated/ABC_097_1_009_1.json
