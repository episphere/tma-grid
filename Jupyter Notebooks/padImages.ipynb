# %%
import os
import json
from PIL import Image

import os
import json
from PIL import Image
def pad_and_crop_image_and_update_labels(image_path, label_path, output_image_path, output_label_path, desired_height=1024, desired_width=1024):
    # Open the image
    image = Image.open(image_path)
    original_width, original_height = image.size

    # Read the label data
    with open(label_path, 'r') as label_file:
        labels = json.load(label_file)

    # Check if image needs cropping or padding
    if original_width > desired_width or original_height > desired_height:
        # Crop the image
        new_image = image.crop((0, 0, min(desired_width, original_width), min(desired_height, original_height)))

        # Filter out labels that fall outside the desired dimensions
        labels = [label for label in labels if label['x'] < desired_width and label['y'] < desired_height]
    else:
        # Pad the image
        new_image = Image.new("RGB", (max(desired_width, original_width), max(desired_height, original_height)), (255, 255, 255))
        new_image.paste(image, (0, 0))

    # Save the new image
    new_image.save(output_image_path)

    # Save updated labels
    with open(output_label_path, 'w') as label_file:
        json.dump(labels, label_file, indent=4)

    print(f"Processed {image_path}; saved new image to {output_image_path} and labels to {output_label_path}")

# Directory containing images and labels
image_directory = "../TMA_WSI_PNGs"
label_directory = "../TMA_WSI_Labels"

# image_directory = "./augmented_images"
# label_directory = "./augmented_labels"


# output_image_directory = "./augmented_images_updated"
# output_label_directory = "./augmented_labels_updated"

output_image_directory = "./TMA_WSI_Padded_PNGs"
output_label_directory = "./TMA_WSI_Labels_updated"

# Make sure the output directories exist
os.makedirs(output_image_directory, exist_ok=True)
os.makedirs(output_label_directory, exist_ok=True)

# Iterate over all files in the directory
for filename in os.listdir(image_directory):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        image_path = os.path.join(image_directory, filename)
        label_path = os.path.join(label_directory, os.path.splitext(filename)[0] + '.json')
        output_image_path = os.path.join(output_image_directory, filename)
        output_label_path = os.path.join(output_label_directory, os.path.splitext(filename)[0] + '.json')

        if os.path.exists(label_path):
            pad_and_crop_image_and_update_labels(image_path, label_path, output_image_path, output_label_path)
        else:
            print(f"No label found for {filename}, skipping.")
# Out:
# Processed ../TMA_WSI_PNGs/63.png; saved new image to ./TMA_WSI_Padded_PNGs/63.png and labels to ./TMA_WSI_Labels_updated/63.json
# Processed ../TMA_WSI_PNGs/62.png; saved new image to ./TMA_WSI_Padded_PNGs/62.png and labels to ./TMA_WSI_Labels_updated/62.json
# Processed ../TMA_WSI_PNGs/60.png; saved new image to ./TMA_WSI_Padded_PNGs/60.png and labels to ./TMA_WSI_Labels_updated/60.json
# Processed ../TMA_WSI_PNGs/48.png; saved new image to ./TMA_WSI_Padded_PNGs/48.png and labels to ./TMA_WSI_Labels_updated/48.json
# Processed ../TMA_WSI_PNGs/49.png; saved new image to ./TMA_WSI_Padded_PNGs/49.png and labels to ./TMA_WSI_Labels_updated/49.json
# Processed ../TMA_WSI_PNGs/61.png; saved new image to ./TMA_WSI_Padded_PNGs/61.png and labels to ./TMA_WSI_Labels_updated/61.json
# Processed ../TMA_WSI_PNGs/59.png; saved new image to ./TMA_WSI_Padded_PNGs/59.png and labels to ./TMA_WSI_Labels_updated/59.json
# Processed ../TMA_WSI_PNGs/58.png; saved new image to ./TMA_WSI_Padded_PNGs/58.png and labels to ./TMA_WSI_Labels_updated/58.json
# Processed ../TMA_WSI_PNGs/56.png; saved new image to ./TMA_WSI_Padded_PNGs/56.png and labels to ./TMA_WSI_Labels_updated/56.json
# Processed ../TMA_WSI_PNGs/43.png; saved new image to ./TMA_WSI_Padded_PNGs/43.png and labels to ./TMA_WSI_Labels_updated/43.json
# Processed ../TMA_WSI_PNGs/57.png; saved new image to ./TMA_WSI_Padded_PNGs/57.png and labels to ./TMA_WSI_Labels_updated/57.json
# Processed ../TMA_WSI_PNGs/55.png; saved new image to ./TMA_WSI_Padded_PNGs/55.png and labels to ./TMA_WSI_Labels_updated/55.json
# Processed ../TMA_WSI_PNGs/54.png; saved new image to ./TMA_WSI_Padded_PNGs/54.png and labels to ./TMA_WSI_Labels_updated/54.json
# Processed ../TMA_WSI_PNGs/44.png; saved new image to ./TMA_WSI_Padded_PNGs/44.png and labels to ./TMA_WSI_Labels_updated/44.json
# Processed ../TMA_WSI_PNGs/50.png; saved new image to ./TMA_WSI_Padded_PNGs/50.png and labels to ./TMA_WSI_Labels_updated/50.json
# Processed ../TMA_WSI_PNGs/51.png; saved new image to ./TMA_WSI_Padded_PNGs/51.png and labels to ./TMA_WSI_Labels_updated/51.json
# Processed ../TMA_WSI_PNGs/45.png; saved new image to ./TMA_WSI_Padded_PNGs/45.png and labels to ./TMA_WSI_Labels_updated/45.json
# Processed ../TMA_WSI_PNGs/53.png; saved new image to ./TMA_WSI_Padded_PNGs/53.png and labels to ./TMA_WSI_Labels_updated/53.json
# Processed ../TMA_WSI_PNGs/47.png; saved new image to ./TMA_WSI_Padded_PNGs/47.png and labels to ./TMA_WSI_Labels_updated/47.json
# Processed ../TMA_WSI_PNGs/46.png; saved new image to ./TMA_WSI_Padded_PNGs/46.png and labels to ./TMA_WSI_Labels_updated/46.json
# Processed ../TMA_WSI_PNGs/52.png; saved new image to ./TMA_WSI_Padded_PNGs/52.png and labels to ./TMA_WSI_Labels_updated/52.json
