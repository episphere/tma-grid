# %%
import os
import json
from PIL import Image

import os
import json
from PIL import Image
def pad_and_crop_image_and_update_labels(image_path, label_path, output_image_path, output_label_path, desired_height=1024, desired_width=1024):
    # Open the image
    image = Image.open(image_path)
    original_width, original_height = image.size

    # Read the label data
    with open(label_path, 'r') as label_file:
        labels = json.load(label_file)

    # Check if image needs cropping or padding
    if original_width > desired_width or original_height > desired_height:
        # Crop the image
        new_image = image.crop((0, 0, min(desired_width, original_width), min(desired_height, original_height)))

        # Filter out labels that fall outside the desired dimensions
        labels = [label for label in labels if label['x'] < desired_width and label['y'] < desired_height]
    else:
        # Pad the image
        new_image = Image.new("RGB", (max(desired_width, original_width), max(desired_height, original_height)), (255, 255, 255))
        new_image.paste(image, (0, 0))

    # Save the new image
    new_image.save(output_image_path)

    # Save updated labels
    with open(output_label_path, 'w') as label_file:
        json.dump(labels, label_file, indent=4)

    print(f"Processed {image_path}; saved new image to {output_image_path} and labels to {output_label_path}")

# Directory containing images and labels
image_directory = "../Training_data/PBCS_WSI"
label_directory = "../Training_data/PBCS_WSI_Labels"

# image_directory = "./augmented_images"
# label_directory = "./augmented_labels"


# output_image_directory = "./augmented_images_updated"
# output_label_directory = "./augmented_labels_updated"

output_image_directory = "../Training_data/PBCS_WSI_Padded_PNGs"
output_label_directory = "../Training_data/PBCS_WSI_Labels_updated"

# Make sure the output directories exist
os.makedirs(output_image_directory, exist_ok=True)
os.makedirs(output_label_directory, exist_ok=True)

# Iterate over all files in the directory
for filename in os.listdir(image_directory):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
        image_path = os.path.join(image_directory, filename)
        label_path = os.path.join(label_directory, os.path.splitext(filename)[0] + '.json')
        output_image_path = os.path.join(output_image_directory, filename)
        output_label_path = os.path.join(output_label_directory, os.path.splitext(filename)[0] + '.json')

        if os.path.exists(label_path):
            pad_and_crop_image_and_update_labels(image_path, label_path, output_image_path, output_label_path)
        else:
            print(f"No label found for {filename}, skipping.")
# Out:
# Processed ../Training_data/PBCS_WSI/HE_PBC_905_1_009_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/HE_PBC_905_1_009_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated/HE_PBC_905_1_009_1.json
# Processed ../Training_data/PBCS_WSI/CD163_PBC_915_1_305_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/CD163_PBC_915_1_305_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated/CD163_PBC_915_1_305_1.json
# Processed ../Training_data/PBCS_WSI/63.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/63.png and labels to ../Training_data/PBCS_WSI_Labels_updated/63.json
# Processed ../Training_data/PBCS_WSI/BCL2_PBC_907_1_008_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/BCL2_PBC_907_1_008_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated/BCL2_PBC_907_1_008_1.json
# Processed ../Training_data/PBCS_WSI/CK56_PBC_910_2_007_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/CK56_PBC_910_2_007_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated/CK56_PBC_910_2_007_1.json
# Processed ../Training_data/PBCS_WSI/HER2_PBC_907_2_302_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/HER2_PBC_907_2_302_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated/HER2_PBC_907_2_302_1.json
# Processed ../Training_data/PBCS_WSI/EGFR_PBC_908_1_301_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/EGFR_PBC_908_1_301_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated/EGFR_PBC_908_1_301_1.json
# Processed ../Training_data/PBCS_WSI/BCL2_PBC_905_2_008_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/BCL2_PBC_905_2_008_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated/BCL2_PBC_905_2_008_1.json
# Processed ../Training_data/PBCS_WSI/EGFR_PBC_914_1_301_1.png; saved new image to ../Training_data/PBCS_WSI_Padded_PNGs/EGFR_PBC_914_1_301_1.png and labels to ../Training_data/PBCS_WSI_Labels_updated